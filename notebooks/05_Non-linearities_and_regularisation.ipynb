# %% [markdown]
# # Regularisation
#
# In this lab we will explore different methods for regularising networks to reduce overfitting and improve generalisation. This uses the material covered in the [fourth lecture slides](http://www.inf.ed.ac.uk/teaching/courses/mlp/2018-19/mlp04-reg.pdf).

# %% [markdown]
# # Exercise 1: L1 and L2 penalties
#
# In the previous lab notebook we explored the issue of overfitting. There we saw that this arises when the model is 'too complex' ($\sim$ has too many degrees of freedom / parameters) for the amount of data we have available.
#
# One method for trying to reduce overfitting is therefore to try to decrease the flexibility of the model. We can do this by simply reducing the number of free parameters in the model (e.g. by using a shallower model with fewer layers or layers with smaller dimensionality). More generally however we might want some way of more continuously varying the effective flexibility of a model with a fixed architecture.
#
# A common method for doing this is to add an additional term to the objective function being minimised during training which penalises some measure of the complexity of a model as a function of the model parameters. The aim of training is then to minimise with respect to the model parameters the sum $E^\star$ of the data-driven error function term $\bar{E}$ and a model complexity term $C$.
#
# \begin{equation}
#    E^\star =
#    \underbrace{\bar{E}}_{\textrm{data term}} + \underbrace{C}_{\textrm{complexity term}}
# \end{equation}
#
# We need the complexity term $C$ to be easy to compute and differentiable with respect to the model parameters. A common choice is to use terms involving the *norms* ($\sim$ a measure of size) of the parameters. This penalises models with large parameter values. Two commonly used norms are the L1 and L2 norms.
#
# For a $D$ dimensional vector $\mathbf{v}$ the L1 norm is defined as
#
# \begin{equation}
# \| \boldsymbol{v} \|_1 = \sum_{d=1}^D \left| v_d \right|,
# \end{equation}
#
# and the L2 norm is defined as
#
# \begin{equation}
# \| \boldsymbol{v} \|_2 = \left[ \sum_{d=1}^D \left( v_d^2 \right) \right]^{\frac{1}{2}}.
# \end{equation}
#
# For a $K \times D$ matrix $\mathbf{M}$, we will define norms by collapsing the matrix to a vector $\boldsymbol{m} = \mathrm{vec}\left[\mathbf{M}\right] = \left[ M_{1,1} \dots M_{1,D} ~ M_{2,1} \dots M_{K,D} \right]^{\rm T}$ and then taking the norm as defined above of this resulting vector (practically this just results in summing over two sets of indices rather than one).
#
# The overall complexity penalty term $C$ is defined as a sum over individual complexity terms for each of the $P$ parameters of the model
#
# \begin{equation}
#     C = \sum_{i=1}^P \left[ C^{(i)} \right]
# \end{equation}
#
# Some of these per-parameter penalty terms $C^{(i)}$ may be set to zero if we do not wish to penalise the size of the corresponding parameter.
#
# To enable us to tradeoff between the model complexity and data error terms, it is typical to introduce positive scalar coefficients $\beta_i$ to scale the penalty term on the $i$th parameter. A *L1 penalty* on the $i$th vector parameter $\boldsymbol{p}^{(i)}$ (or matrix parameter collapsed to a vector) is then commonly defined as
#
# \begin{equation}
#   C^{(i)}_{\textrm{L1}} =
#   \beta_i \left\| \boldsymbol{p}^{(i)} \right\|_1 =
#   \beta_i  \sum_{d=1}^D \left| p^{(i)}_d \right|.
# \end{equation}
#
# This has a gradient with respect to the parameter vector
#
# \begin{equation}
#   \frac{\partial C^{(i)}_{\textrm{L1}}}{\partial p^{(i)}_d} = \beta_i \, \textrm{sgn}\left( p^{(i)}_d \right)
# \end{equation}
#
# where $\textrm{sgn}(u) = +1$ if $u > 0$, $\textrm{sgn}(u) = -1$ if $u < 0$ (and is not well defined for $u=0$ though a common convention is to have $\textrm{sgn}(0) = 0$).
#
# Similarly a *L2 penalty* on the $i$th vector parameter $\boldsymbol{p}^{(i)}$ (or matrix parameter collapsed to a vector) is commonly defined as
#
# \begin{equation}
#   C^{(i)}_{\textrm{L2}} =
#   \frac{1}{2} \beta_i \left\| \boldsymbol{p}^{(i)} \right\|_2^2 =
#   \frac{1}{2} \beta_i \sum_{d=1}^D \left[ \left( p^{(i)}_d \right)^2 \right].
# \end{equation}
#
# Somewhat confusingly this is proportional to the square of the L2 norm rather than the L2 norm itself, however it is an almost universal convention to call this an L2 penalty so we will stick with this nomenclature here. The $\frac{1}{2}$ term is less universal and is sometimes not included; we include it here for consistency with how we defined the sum of squared errors cost. Similarly to that case, the $\frac{1}{2}$ cancels when calculating the gradient with respect to the parameter
#
# \begin{equation}
#   \frac{\partial C^{(i)}_{\textrm{L2}}}{\partial p^{(i)}_d} = \beta_i p^{(i)}_d
# \end{equation}
#
# Use the above definitions for the L1 and L2 penalties for a parameter and corresponding gradients to implement the `__call__` and `grad` methods respectively for the skeleton `L1Penalty` and `L2Penalty` class definitions below. The `coefficient` property of these classes should be used as the $\beta_i$ value in the equations above. The parameter the penalty term (or gradient) is being evaluated for will be either a one or two-dimensional NumPy array (corresponding to a vector or matrix parameter respectively) and your implementations should be able to cope with both cases.

# %%
import numpy as np
seed = 22102017 
rng = np.random.RandomState(seed)
class L1Penalty(object):
    """L1 parameter penalty.
    
    Term to add to the objective function penalising parameters
    based on their L1 norm.
    """
    
    def __init__(self, coefficient):
        """Create a new L1 penalty object.
        
        Args:
            coefficient: Positive constant to scale penalty term by.
        """
        assert coefficient > 0., 'Penalty coefficient must be positive.'
        self.coefficient = coefficient
        
    def __call__(self, parameter):
        """Calculate L1 penalty value for a parameter.
        
        Args:
            parameter: Array corresponding to a model parameter.
            
        Returns:
            Value of penalty term.
        """
        return self.coefficient * np.sum(np.abs(parameter))
        
    def grad(self, parameter):
        """Calculate the penalty gradient with respect to the parameter.
        
        Args:
            parameter: Array corresponding to a model parameter.
            
        Returns:
            Value of penalty gradient with respect to parameter. This
            should be an array of the same shape as the parameter.
        """
        return self.coefficient * np.sign(parameter)
    
    def __repr__(self):
        return 'L1Penalty({0})'.format(self.coefficient)
        

class L2Penalty(object):
    """L1 parameter penalty.
    
    Term to add to the objective function penalising parameters
    based on their L2 norm.
    """

    def __init__(self, coefficient):
        """Create a new L2 penalty object.
        
        Args:
            coefficient: Positive constant to scale penalty term by.
        """
        assert coefficient > 0., 'Penalty coefficient must be positive.'
        self.coefficient = coefficient
        
    def __call__(self, parameter):
        """Calculate L2 penalty value for a parameter.
        
        Args:
            parameter: Array corresponding to a model parameter.
            
        Returns:
            Value of penalty term.
        """
        return self.coefficient * 0.5 * np.sum(parameter**2)
        
    def grad(self, parameter):
        """Calculate the penalty gradient with respect to the parameter.
        
        Args:
            parameter: Array corresponding to a model parameter.
            
        Returns:
            Value of penalty gradient with respect to parameter. This
            should be an array of the same shape as the parameter.
        """
        return self.coefficient * parameter
    
    def __repr__(self):
        return 'L2Penalty({0})'.format(self.coefficient)

# %% [markdown]
# Test your implementations by running the cells below.

# %%
test_params_1 = np.array([[0.5, 0.3, -1.2, 5.8], [0.2, -3.1, 4.9, -5.0]])
test_params_2 = np.array([0.8, -0.6, -0.3, 1.5, 2.8])
true_l1_cost_1 = 10.5
true_l1_grad_1 = np.array([[0.5, 0.5, -0.5, 0.5], [0.5, -0.5, 0.5, -0.5]])
true_l1_cost_2 = 3.
true_l1_grad_2 = np.array([0.5, -0.5, -0.5, 0.5, 0.5])
l1 = L1Penalty(0.5)
if (not np.allclose(l1(test_params_1), true_l1_cost_1) or
        not np.allclose(l1(test_params_2), true_l1_cost_2)):
    print('L1Penalty.__call__ giving incorrect value(s).')
elif (not np.allclose(l1.grad(test_params_1), true_l1_grad_1) or 
          not np.allclose(l1.grad(test_params_2), true_l1_grad_2)):
    print('L1Penalty.grad giving incorrect value(s).')
else:
    print('All test values calculated correctly for L1Penalty')
# Out:
# All test values calculated correctly for L1Penalty

# %%
test_params_1 = np.array([[0.5, 0.3, -1.2, 5.8], [0.2, -3.1, 4.9, -5.0]])
test_params_2 = np.array([0.8, -0.6, -0.3, 1.5, 2.8])
true_l2_cost_1 = 23.52
true_l2_grad_1 = np.array([[0.25, 0.15,_ = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, params)2), true_l2_cost_2)):
    print('L2Penalty.__call__ giving incorrect value(s).')
elif (not np.allclose(l2.grad(test_params_1), true_l2_grad_1) or 
          not np.allclose(l2.grad(test_params_2), true_l2_grad_2)):
    print('L2Penalty.grad giving incorrect value(s).')
else:
    print('All test values calculated correctly for L2Penalty')
# Out:
# All test values calculated correctly for L2Penalty

# %% [markdown]
# ## Exercise 2: Training with regularisation

# %% [markdown]
# Previously in the second laboratory you implemented a function `grads_wrt_params`  to calculate the gradient of an error function with respect to the parameters of an affine model (layer), given gradients of the error function with respect to the model (layer) outputs.
#
# If we are training a model using a regularised objective function, we need to additionally calculate the gradients of the regularisation penalty terms with respect to the parameters and add these to the error function gradient terms. Following from the definition of the regularised objective $E^\star$ above we have that the gradient of the overall objective with respect to the $d$th element of the $i$th model parameter is
#
# \begin{equation}
#     \frac{\partial E^\star}{\partial p^{(i)}_d} =
#     \frac{\partial \bar{E}}{\partial p^{(i)}_d} +
#     \frac{\partial C}{\partial p^{(i)}_d}
# \end{equation}
#
# We have already discussed in the second lab notebook how to calculate the error function gradient term $\frac{\partial \bar{E}}{\partial p^{(i)}_d}$. As the model complexity term is composed of a sum of per parameter terms and only one of these will depend on the $i$th parameter we can write
#
# \begin{equation}
#     \frac{\partial C}{\partial p^{(i)}_d} = \frac{\partial C^{(i)}}{\partial p^{(i)}_d}
# \end{equation}
#
# which corresponds to the penalty term gradients you implemented above. To enable us to use the same `Optimiser` implementation that we have previously used to train models without regularisation, we have altered the implementation of the `AffineLayer` class to allow us to specify penalty terms on the weight matrix and bias vector when creating an instance of the class and to add the corresponding penalty gradients to the returned value from the `grads_wrt_params` method.
#
# The penalty terms need to be specified as a class matching the interface of the `L1Penalty` and `L2Penalty` classes you implemented above, defining both a `__call__` method to calculate the penalty value for a parameter and a `grad` method to calculate the gradient of the penalty with respect to the parameter. Separate penalties can be specified for the weight and bias parameters, with it common to only regularise the weight parameters.
#
# The penalty terms for a layer are specifed using the `weights_penalty` and `biases_penalty` arguments to the `__init__` method of the `AffineLayer` class. If either (or both) of these are set to `None` (the default) no regularisation is applied to the corresponding parameter.
#
# Using the `L1Penalty` and `L2Penalty` classes you implemented in the previous exercise, train models to classify MNIST digit images with
#
#   * no regularisation
#   * an L1 penalty with coefficient $10^{-5}$ on the all of the weight matrix parameters
#   * an L1 penalty with coefficient $10^{-3}$ on the all of the weight matrix parameters
#   * an L2 penalty with coefficient $10^{-4}$ on the all of the weight matrix parameters
#   * an L2 penalty with coefficient $10^{-2}$ on the all of the weight matrix parameters
#
# The models should all have three affine layers each interspersed with a `ReluLayer` (as implemented in the Lab 3 on Multiple Layer Models) and intermediate layers between the input and output should have dimensionalities of 100. The final output layer should be an `AffineLayer` (the model outputting the logarithms of the non-normalised class probabilties) and you should use the `CrossEntropySoftmaxError` as the error function (which calculates the softmax of the model outputs to convert to normalised class probabilities before calculating the corresponding multi-class cross entropy error).
#
# Use the `GlorotInit` class (which implements the weight initialisation technique discussed in the [fifth lecture](http://www.inf.ed.ac.uk/teaching/courses/mlp/2018-19/mlp05-learn.pdf)) to initialise the weights in all layers, using a gain of 0.5 (this adjusts for the fact that the rectified linear sets zeros all negative inputs), and initialises the biases to zero with a `ConstantInit` object.
#
# As an example the necessary parameter initialisers, model and error can be defined using
#
# ```python
# weights_init = GlorotUniformInit(0.5, rng)
# biases_init = ConstantInit(0.)
# input_dim, output_dim, hidden_dim = 784, 10, 100
# model = MultipleLayerModel([
#     AffineLayer(input_dim, hidden_dim, weights_init,
#                 biases_init, weights_penalty=weights_penalty),
#     ReluLayer(),
#     AffineLayer(hidden_dim, hidden_dim, weights_init,
#                 biases_init, weights_penalty=weights_penalty),
#     ReluLayer(),
#     AffineLayer(hidden_dim, output_dim, weights_init,
#                 biases_init, weights_penalty=weights_penalty)
# ])
# error = CrossEntropySoftmaxError()
# ```
#
# This assumes all the relevant classes have been imported from their modules, a penalty object has been assigned to `weights_penalty` and a seeded random number generator assigned to `rng`.
#
# For each regularisation scheme, train the model for 100 epochs with a batch size of 50 and using a gradient descent with momentum learning rule with learning rate 0.01 and momentum coefficient 0.9. For each regularisation scheme you should store the run statistics (output of `Optimiser.train`) and the final values of the first layer weights for each of the trained models.

# %%
import matplotlib.pyplot as plt
import logging
from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer
from mlp.errors import CrossEntropyError, CrossEntropySoftmaxError, SumOfSquaredDiffsError
from mlp.models import SingleLayerModel, MultipleLayerModel
from mlp.initialisers import *
from mlp.learning_rules import *
from mlp.data_providers import MNISTDataProvider
from mlp.optimisers import Optimiser

def train_model_and_plot_stats(
        model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, params):
    # As well as monitoring the error over training also monitor classification
    # accuracy i.e. proportion of most-probable predicted classes being equal to targets
    data_monitors = {'acc': lambda y, t: (y.argmax(-1) == t.argmax(-1)).mean()}

    # Use the created objects to initialise a new Optimiser instance.
    optimiser = Optimiser(
        model, error, learning_rule, train_data, valid_data, data_monitors)

    # Run the optimiser for 5 epochs (full passes through the training set)
    # printing statistics every epoch.
    stats, keys, _ = optimiser.train(num_epochs=num_epochs, stats_interval=stats_interval)

    # Plot the change in the validation and training set error over training.
    figs = []
    axs = []
    fig_1 = plt.figure(figsize=(8, 4))
    ax_1 = fig_1.add_subplot(111)
    for k in ['error(train)', 'error(valid)']:
        ax_1.plot(np.arange(1, stats.shape[0]) * stats_interval,
                  stats[1:, keys[k]], label=k)
    ax_1.legend(loc=0)
    ax_1.set_title(label=str(params))
    ax_1.set_xlabel('Epoch number')
    figs.append(fig_1)
    axs.append(ax_1)

    # Plot the change in the validation and training set accuracy over training.
    fig_2 = plt.figure(figsize=(8, 4))
    ax_2 = fig_2.add_subplot(111)
    for k in ['acc(train)', 'acc(valid)']:
        ax_2.plot(np.arange(1, stats.shape[0]) * stats_interval,
                  stats[1:, keys[k]], label=k)
    ax_2.legend(loc=0)
    ax_2.set_title(label=str(params))
    ax_2.set_xlabel('Epoch number')
    figs.append(fig_2)
    axs.append(ax_2)

    # Plot the change in the validation and training error gradients w.r.t the ouputs.
    fig_3 = plt.figure(figsize=(8, 4))
    ax_3 = fig_3.add_subplot(111)
    for k in ['grads_output(train)', 'grads_output(valid)']:
        ax_3.plot(np.arange(1, stats.shape[0]) * stats_interval,
                  stats[1:, keys[k]], label=k)
    ax_3.legend(loc=0)
    ax_3.set_title(label=str(params))
    ax_3.set_xlabel('Epoch number')
    figs.append(fig_3)
    axs.append(ax_3)

    # Plot the change in the validation and training error gradients w.r.t the ouputs.
    fig_4 = plt.figure(figsize=(8, 4))
    ax_4 = fig_4.add_subplot(111)
    for k in ['grads_weights(train)']:
        ax_4.plot(np.arange(1, stats.shape[0]) * stats_interval,
                  stats[1:, keys[k]], label=k)
    ax_4.legend(loc=0)
    ax_4.set_title(label=str(params))
    ax_4.set_xlabel('Epoch number')
    figs.append(fig_4)
    axs.append(ax_4)

    # Plot the change in the validation and training error gradients w.r.t the ouputs.
    fig_5 = plt.figure(figsize=(8, 4))
    ax_5 = fig_5.add_subplot(111)
    for k in ['grads_biases(train)']:
        ax_5.plot(np.arange(1, stats.shape[0]) * stats_interval,
                  stats[1:, keys[k]], label=k)
    ax_5.legend(loc=0)
    ax_5.set_title(label=str(params))
    ax_5.set_xlabel('Epoch number')
    figs.append(fig_5)
    axs.append(ax_5)

    return stats, keys, model, figs, axs

# Set up a logger object to print info about the training run to stdout
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.handlers = [logging.StreamHandler()]

# Create data provider objects for the MNIST data set
train_data = MNISTDataProvider('train', rng=rng)
valid_data = MNISTDataProvider('valid', rng=rng)

# %%
# Set training run hyperparameters
batch_size = 50  # number of data points in a batch
learning_rate = 0.01  # learning rate for gradient descent
num_epochs = 100  # number of training epochs to perform
stats_interval = 5  # epoch interval between recording and printing stats
input_dim, output_dim, hidden_dim = 784, 10, 100
regularisation = 'l1'
reg_coefficient = 1e-5

params = {'regularisation': regularisation,
          'alpha': reg_coefficient,
          }

if regularisation == 'l1':
    weights_penalty = L1Penalty(reg_coefficient)
elif regularisation == 'l2':
    weights_penalty = L2Penalty(reg_coefficient)

# Reset random number generator and data provider states on each run
# to ensure reproducibility of results
rng.seed(seed)
train_data.reset()
valid_data.reset()

# Alter data-provider batch size
train_data.batch_size = batch_size
valid_data.batch_size = batch_size

# Create a parameter initialiser which will sample random uniform values
# from [-init_scale, init_scale]
#param_init = UniformInit(-init_scale, init_scale, rng=rng)
weights_init = GlorotUniformInit(0.5, rng)
biases_init = ConstantInit(0.)

# Create affine model (outputs are logs of unnormalised class probabilities)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init, weights_penalty=weights_penalty),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_penalty=weights_penalty),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init, weights_penalty=weights_penalty),]
)

# Initialise the error object
error = CrossEntropySoftmaxError()

# Use a basic gradient descent learning rule
learning_rule = MomentumLearningRule(learning_rate=learning_rate)

_ = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, params)
# Out:
# Epoch 5: 1.6s to complete
#     error(train)=7.02e-02, grads_output(train)=1.62e-04, grads_weights(train)=1.68e-03, grads_biases(train)=8.64e-03, acc(train)=9.79e-01, error(valid)=1.02e-01, grads_output(valid)=1.88e-04, grads_weights(valid)=1.68e-03, grads_biases(valid)=8.64e-03, acc(valid)=9.71e-01
# Epoch 10: 1.7s to complete
#     error(train)=3.47e-02, grads_output(train)=8.54e-05, grads_weights(train)=1.16e-03, grads_biases(train)=8.98e-03, acc(train)=9.90e-01, error(valid)=8.48e-02, grads_output(valid)=1.34e-04, grads_weights(valid)=1.16e-03, grads_biases(valid)=8.98e-03, acc(valid)=9.76e-01
# Epoch 15: 1.5s to complete
#     error(train)=1.79e-02, grads_output(train)=5.03e-05, grads_weights(train)=1.09e-03, grads_biases(train)=6.69e-03, acc(train)=9.95e-01, error(valid)=9.27e-02, grads_output(valid)=1.21e-04, grads_weights(valid)=1.09e-03, grads_biases(valid)=6.69e-03, acc(valid)=9.76e-01
# Epoch 20: 1.5s to complete
#     error(train)=6.68e-03, grads_output(train)=2.22e-05, grads_weights(train)=8.30e-04, grads_biases(train)=8.35e-03, acc(train)=9.99e-01, error(valid)=8.04e-02, grads_output(valid)=9.87e-05, grads_weights(valid)=8.30e-04, grads_biases(valid)=8.35e-03, acc(valid)=9.80e-01
# Epoch 25: 1.5s to complete
#     error(train)=3.28e-03, grads_output(train)=1.22e-05, grads_weights(train)=3.75e-04, grads_biases(train)=2.81e-03, acc(train)=1.00e+00, error(valid)=8.36e-02, grads_output(valid)=9.64e-05, grads_weights(valid)=3.75e-04, grads_biases(valid)=2.81e-03, acc(valid)=9.79e-01
# Epoch 30: 1.5s to complete
#     error(train)=2.44e-03, grads_output(train)=9.29e-06, grads_weights(train)=3.41e-05, grads_biases(train)=1.89e-04, acc(train)=1.00e+00, error(valid)=8.44e-02, grads_output(valid)=9.33e-05, grads_weights(valid)=3.41e-05, grads_biases(valid)=1.89e-04, acc(valid)=9.81e-01
# Epoch 35: 1.5s to complete
#     error(train)=2.18e-03, grads_output(train)=8.45e-06, grads_weights(train)=4.12e-05, grads_biases(train)=2.49e-04, acc(train)=1.00e+00, error(valid)=8.60e-02, grads_output(valid)=9.56e-05, grads_weights(valid)=4.12e-05, grads_biases(valid)=2.49e-04, acc(valid)=9.80e-01
# Epoch 40: 1.5s to complete
#     error(train)=1.92e-03, grads_output(train)=7.46e-06, grads_weights(train)=3.46e-05, grads_biases(train)=1.89e-04, acc(train)=1.00e+00, error(valid)=8.43e-02, grads_output(valid)=9.28e-05, grads_weights(valid)=3.46e-05, grads_biases(valid)=1.89e-04, acc(valid)=9.80e-01
# Epoch 45: 1.5s to complete
#     error(train)=2.19e-03, grads_output(train)=8.44e-06, grads_weights(train)=2.74e-05, grads_biases(train)=1.10e-04, acc(train)=1.00e+00, error(valid)=8.53e-02, grads_output(valid)=9.25e-05, grads_weights(valid)=2.74e-05, grads_biases(valid)=1.10e-04, acc(valid)=9.80e-01
# Epoch 50: 1.5s to complete
#     error(train)=5.81e-03, grads_output(train)=1.93e-05, grads_weights(train)=1.18e-04, grads_biases(train)=6.41e-04, acc(train)=9.99e-01, error(valid)=9.20e-02, grads_output(valid)=9.96e-05, grads_weights(valid)=1.18e-04, grads_biases(valid)=6.41e-04, acc(valid)=9.78e-01
# Epoch 55: 1.5s to complete
#     error(train)=9.43e-03, grads_output(train)=2.62e-05, grads_weights(train)=1.22e-03, grads_biases(train)=8.88e-03, acc(train)=9.97e-01, error(valid)=9.77e-02, grads_output(valid)=1.03e-04, grads_weights(valid)=1.22e-03, grads_biases(valid)=8.88e-03, acc(valid)=9.78e-01
# Epoch 60: 1.5s to complete
#     error(train)=1.03e-03, grads_output(train)=4.04e-06, grads_weights(train)=4.93e-05, grads_biases(train)=3.60e-04, acc(train)=1.00e+00, error(valid)=8.62e-02, grads_output(valid)=8.80e-05, grads_weights(valid)=4.93e-05, grads_biases(valid)=3.60e-04, acc(valid)=9.81e-01
# Epoch 65: 1.5s to complete
#     error(train)=1.02e-03, grads_output(train)=4.01e-06, grads_weights(train)=7.46e-05, grads_biases(train)=7.58e-04, acc(train)=1.00e+00, error(valid)=8.48e-02, grads_output(valid)=8.86e-05, grads_weights(valid)=7.46e-05, grads_biases(valid)=7.58e-04, acc(valid)=9.81e-01
# Epoch 70: 1.4s to complete
#     error(train)=1.20e-03, grads_output(train)=4.74e-06, grads_weights(train)=4.52e-05, grads_biases(train)=2.74e-04, acc(train)=1.00e+00, error(valid)=8.32e-02, grads_output(valid)=8.98e-05, grads_weights(valid)=4.52e-05, grads_biases(valid)=2.74e-04, acc(valid)=9.81e-01
# Epoch 75: 1.4s to complete
#     error(train)=1.27e-03, grads_output(train)=5.02e-06, grads_weights(train)=9.26e-05, grads_biases(train)=5.00e-04, acc(train)=1.00e+00, error(valid)=8.23e-02, grads_output(valid)=9.07e-05, grads_weights(valid)=9.26e-05, grads_biases(valid)=5.00e-04, acc(valid)=9.81e-01
# Epoch 80: 1.4s to complete
#     error(train)=1.39e-03, grads_output(train)=5.49e-06, grads_weights(train)=2.37e-05, grads_biases(train)=1.13e-04, acc(train)=1.00e+00, error(valid)=8.22e-02, grads_output(valid)=9.12e-05, grads_weights(valid)=2.37e-05, grads_biases(valid)=1.13e-04, acc(valid)=9.81e-01
# Epoch 85: 1.4s to complete
#     error(train)=1.47e-03, grads_output(train)=5.80e-06, grads_weights(train)=6.64e-05, grads_biases(train)=3.14e-04, acc(train)=1.00e+00, error(valid)=8.22e-02, grads_output(valid)=9.34e-05, grads_weights(valid)=6.64e-05, grads_biases(valid)=3.14e-04, acc(valid)=9.80e-01
# Epoch 90: 1.4s to complete
#     error(train)=1.49e-03, grads_output(train)=5.85e-06, grads_weights(train)=3.95e-05, grads_biases(train)=2.21e-04, acc(train)=1.00e+00, error(valid)=8.23e-02, grads_output(valid)=9.34e-05, grads_weights(valid)=3.95e-05, grads_biases(valid)=2.21e-04, acc(valid)=9.80e-01
# Epoch 95: 1.4s to complete
#     error(train)=1.80e-02, grads_output(train)=4.40e-05, grads_weights(train)=5.97e-04, grads_biases(train)=3.68e-03, acc(train)=9.94e-01, error(valid)=1.08e-01, grads_output(valid)=1.22e-04, grads_weights(valid)=5.97e-04, grads_biases(valid)=3.68e-03, acc(valid)=9.74e-01
# Epoch 100: 1.4s to complete
#     error(train)=6.12e-03, grads_output(train)=1.74e-05, grads_weights(train)=1.72e-04, grads_biases(train)=9.99e-04, acc(train)=9.98e-01, error(valid)=9.91e-02, grads_output(valid)=9.75e-05, grads_weights(valid)=1.72e-04, grads_biases(valid)=9.99e-04, acc(valid)=9.78e-01

# %% [markdown]
# Plot the training set error against epoch number for all different regularisation schemes on the same axis. On a second axis plot the validation set error against epoch number for all the different regularisation schemes. Interpret and comment on what you see.

# %%
def plot_all_errors(Stats, Params):

    fig_1 = plt.figure(figsize=(8, 4))
    ax_1 = fig_1.add_subplot(111)
    for stats, params in zip(Stats, Params):
        for k in ['error(train)']:
            ax_1.plot(np.arange(1, stats.shape[0]) * stats_interval,
                    stats[1:, keys[k]], label=str(params))
        ax_1.legend(loc=0)
        ax_1.set_title(label=k)
        ax_1.set_xlabel('Epoch number')
    
    fig_2 = plt.figure(figsize=(8, 4))
    ax_2 = fig_2.add_subplot(111)
    for stats, params in zip(Stats, Params):
        for k in ['error(valid)']:
            ax_2.plot(np.arange(1, stats.shape[0]) * stats_interval,
                    stats[1:, keys[k]], label=str(params))
        ax_2.legend(loc=0)
        ax_2.set_title(label=k)
        ax_2.set_xlabel('Epoch number')

    return fig_1, ax_1, fig_2, ax_2

def initialise_model(input_dim, hidden_dim, weights_init, biases_init, weights_penalty):

    model = MultipleLayerModel([
        AffineLayer(input_dim, hidden_dim, weights_init, biases_init, weights_penalty=weights_penalty),
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_penalty=weights_penalty),
        ReluLayer(),
        AffineLayer(hidden_dim, output_dim, weights_init, biases_init, weights_penalty=weights_penalty),]
    )

    return model

# %%
# Parameters constant accross runs
# Set training run hyperparameters
batch_size = 50  # number of data points in a batch
learning_rate = 0.01  # learning rate for gradient descent
num_epochs = 100  # number of training epochs to perform
stats_interval = 5  # epoch interval between recording and printing stats
input_dim, output_dim, hidden_dim = 784, 10, 100

assert num_epochs >= stats_interval
# reset rng
rng.seed(seed)

# Create a parameter initialiser which will sample random uniform values
# from [-init_scale, init_scale]
#param_init = UniformInit(-init_scale, init_scale, rng=rng)
weights_init = GlorotUniformInit(0.5, rng)
biases_init = ConstantInit(0.)
# Initialise the error object
error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = MomentumLearningRule(learning_rate=learning_rate)

Regularisations = {'None' : [None], 'l1' : [1e-5, 1e-3] , 'l2' : [1e-4, 1e-2]}

#Store results
Params = []
Stats = []
Models = []

for reg_scheme, coefficients in Regularisations.items():
    for reg_coefficient in coefficients:
        if reg_scheme == 'l1': weights_penalty = L1Penalty(reg_coefficient)
        elif reg_scheme == 'l2': weights_penalty = L2Penalty(reg_coefficient)
        else: weights_penalty = None
        
        params = {'regularisation': reg_scheme,
        'alpha': reg_coefficient,
        }
        Params.append(params)

        # Reset random number generator and data provider states on each run
        # to ensure reproducibility of results
        rng.seed(seed)
        train_data.reset()
        valid_data.reset()

        # Alter data-provider batch size
        train_data.batch_size = batch_size
        valid_data.batch_size = batch_size

        model = initialise_model(input_dim, hidden_dim, weights_init, biases_init, weights_penalty)

        stats, keys, model, figs, axs = train_model_and_plot_stats(
        model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, params)
        Stats.append(stats)
        Models.append(model)

fig_train, ax_train, fig_valid, ax_valid = plot_all_errors(Stats, Params)
# Out:
# Epoch 5: 1.3s to complete
#     error(train)=6.86e-02, grads_output(train)=1.57e-04, grads_weights(train)=1.76e-03, grads_biases(train)=9.17e-03, acc(train)=9.79e-01, error(valid)=1.01e-01, grads_output(valid)=1.84e-04, grads_weights(valid)=1.76e-03, grads_biases(valid)=9.17e-03, acc(valid)=9.69e-01
# Epoch 10: 1.3s to complete
#     error(train)=3.02e-02, grads_output(train)=7.43e-05, grads_weights(train)=1.13e-03, grads_biases(train)=1.00e-02, acc(train)=9.91e-01, error(valid)=8.64e-02, grads_output(valid)=1.29e-04, grads_weights(valid)=1.13e-03, grads_biases(valid)=1.00e-02, acc(valid)=9.76e-01
# Epoch 15: 1.3s to complete
#     error(train)=1.40e-02, grads_output(train)=4.00e-05, grads_weights(train)=8.66e-04, grads_biases(train)=6.76e-03, acc(train)=9.97e-01, error(valid)=9.60e-02, grads_output(valid)=1.19e-04, grads_weights(valid)=8.66e-04, grads_biases(valid)=6.76e-03, acc(valid)=9.76e-01
# Epoch 20: 1.3s to complete
#     error(train)=4.17e-03, grads_output(train)=1.44e-05, grads_weights(train)=2.34e-04, grads_biases(train)=2.25e-03, acc(train)=9.99e-01, error(valid)=8.91e-02, grads_output(valid)=9.76e-05, grads_weights(valid)=2.34e-04, grads_biases(valid)=2.25e-03, acc(valid)=9.79e-01
# Epoch 25: 1.3s to complete
#     error(train)=1.73e-03, grads_output(train)=6.56e-06, grads_weights(train)=2.80e-04, grads_biases(train)=2.39e-03, acc(train)=1.00e+00, error(valid)=9.40e-02, grads_output(valid)=9.26e-05, grads_weights(valid)=2.80e-04, grads_biases(valid)=2.39e-03, acc(valid)=9.79e-01
# Epoch 30: 1.3s to complete
#     error(train)=1.01e-03, grads_output(train)=3.94e-06, grads_weights(train)=4.41e-06, grads_biases(train)=3.79e-05, acc(train)=1.00e+00, error(valid)=9.76e-02, grads_output(valid)=9.01e-05, grads_weights(valid)=4.41e-06, grads_biases(valid)=3.79e-05, acc(valid)=9.79e-01
# Epoch 35: 1.3s to complete
#     error(train)=7.14e-04, grads_output(train)=2.82e-06, grads_weights(train)=1.35e-05, grads_biases(train)=1.08e-04, acc(train)=1.00e+00, error(valid)=1.02e-01, grads_output(valid)=9.00e-05, grads_weights(valid)=1.35e-05, grads_biases(valid)=1.08e-04, acc(valid)=9.80e-01
# Epoch 40: 1.3s to complete
#     error(train)=5.44e-04, grads_output(train)=2.16e-06, grads_weights(train)=4.01e-06, grads_biases(train)=3.18e-05, acc(train)=1.00e+00, error(valid)=1.04e-01, grads_output(valid)=8.88e-05, grads_weights(valid)=4.01e-06, grads_biases(valid)=3.18e-05, acc(valid)=9.80e-01
# Epoch 45: 1.3s to complete
#     error(train)=4.50e-04, grads_output(train)=1.79e-06, grads_weights(train)=7.57e-06, grads_biases(train)=5.64e-05, acc(train)=1.00e+00, error(valid)=1.07e-01, grads_output(valid)=8.79e-05, grads_weights(valid)=7.57e-06, grads_biases(valid)=5.64e-05, acc(valid)=9.80e-01
# Epoch 50: 1.3s to complete
#     error(train)=3.91e-04, grads_output(train)=1.55e-06, grads_weights(train)=4.04e-06, grads_biases(train)=2.98e-05, acc(train)=1.00e+00, error(valid)=1.09e-01, grads_output(valid)=8.90e-05, grads_weights(valid)=4.04e-06, grads_biases(valid)=2.98e-05, acc(valid)=9.79e-01
# Epoch 55: 1.3s to complete
#     error(train)=3.29e-04, grads_output(train)=1.31e-06, grads_weights(train)=4.59e-05, grads_biases(train)=3.06e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, grads_output(valid)=8.83e-05, grads_weights(valid)=4.59e-05, grads_biases(valid)=3.06e-04, acc(valid)=9.80e-01
# Epoch 60: 1.3s to complete
#     error(train)=2.89e-04, grads_output(train)=1.15e-06, grads_weights(train)=1.92e-05, grads_biases(train)=1.95e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, grads_output(valid)=8.80e-05, grads_weights(valid)=1.92e-05, grads_biases(valid)=1.95e-04, acc(valid)=9.80e-01
# Epoch 65: 1.3s to complete
#     error(train)=2.56e-04, grads_output(train)=1.02e-06, grads_weights(train)=1.94e-05, grads_biases(train)=1.55e-04, acc(train)=1.00e+00, error(valid)=1.14e-01, grads_output(valid)=8.75e-05, grads_weights(valid)=1.94e-05, grads_biases(valid)=1.55e-04, acc(valid)=9.80e-01
# Epoch 70: 1.3s to complete
#     error(train)=2.30e-04, grads_output(train)=9.15e-07, grads_weights(train)=7.99e-06, grads_biases(train)=6.67e-05, acc(train)=1.00e+00, error(valid)=1.15e-01, grads_output(valid)=8.74e-05, grads_weights(valid)=7.99e-06, grads_biases(valid)=6.67e-05, acc(valid)=9.80e-01
# Epoch 75: 1.3s to complete
#     error(train)=2.09e-04, grads_output(train)=8.34e-07, grads_weights(train)=1.00e-05, grads_biases(train)=9.10e-05, acc(train)=1.00e+00, error(valid)=1.16e-01, grads_output(valid)=8.71e-05, grads_weights(valid)=1.00e-05, grads_biases(valid)=9.10e-05, acc(valid)=9.80e-01
# Epoch 80: 1.3s to complete
#     error(train)=1.91e-04, grads_output(train)=7.61e-07, grads_weights(train)=1.25e-06, grads_biases(train)=1.05e-05, acc(train)=1.00e+00, error(valid)=1.17e-01, grads_output(valid)=8.74e-05, grads_weights(valid)=1.25e-06, grads_biases(valid)=1.05e-05, acc(valid)=9.80e-01
# Epoch 85: 1.3s to complete
#     error(train)=1.75e-04, grads_output(train)=6.99e-07, grads_weights(train)=4.23e-06, grads_biases(train)=1.76e-05, acc(train)=1.00e+00, error(valid)=1.19e-01, grads_output(valid)=8.71e-05, grads_weights(valid)=4.23e-06, grads_biases(valid)=1.76e-05, acc(valid)=9.80e-01
# Epoch 90: 1.3s to complete
#     error(train)=1.61e-04, grads_output(train)=6.42e-07, grads_weights(train)=4.21e-06, grads_biases(train)=2.84e-05, acc(train)=1.00e+00, error(valid)=1.20e-01, grads_output(valid)=8.68e-05, grads_weights(valid)=4.21e-06, grads_biases(valid)=2.84e-05, acc(valid)=9.80e-01
# Epoch 95: 1.3s to complete
#     error(train)=1.50e-04, grads_output(train)=5.99e-07, grads_weights(train)=1.24e-05, grads_biases(train)=7.14e-05, acc(train)=1.00e+00, error(valid)=1.20e-01, grads_output(valid)=8.68e-05, grads_weights(valid)=1.24e-05, grads_biases(valid)=7.14e-05, acc(valid)=9.80e-01
# Epoch 100: 1.3s to complete
#     error(train)=1.40e-04, grads_output(train)=5.58e-07, grads_weights(train)=1.13e-05, grads_biases(train)=9.85e-05, acc(train)=1.00e+00, error(valid)=1.22e-01, grads_output(valid)=8.71e-05, grads_weights(valid)=1.13e-05, grads_biases(valid)=9.85e-05, acc(valid)=9.80e-01
# Epoch 5: 1.5s to complete
#     error(train)=7.02e-02, grads_output(train)=1.62e-04, grads_weights(train)=1.68e-03, grads_biases(train)=8.64e-03, acc(train)=9.79e-01, error(valid)=1.02e-01, grads_output(valid)=1.88e-04, grads_weights(valid)=1.68e-03, grads_biases(valid)=8.64e-03, acc(valid)=9.71e-01
# Epoch 10: 1.5s to complete
#     error(train)=3.47e-02, grads_output(train)=8.54e-05, grads_weights(train)=1.16e-03, grads_biases(train)=8.98e-03, acc(train)=9.90e-01, error(valid)=8.48e-02, grads_output(valid)=1.34e-04, grads_weights(valid)=1.16e-03, grads_biases(valid)=8.98e-03, acc(valid)=9.76e-01
# Epoch 15: 1.5s to complete
#     error(train)=1.79e-02, grads_output(train)=5.03e-05, grads_weights(train)=1.09e-03, grads_biases(train)=6.69e-03, acc(train)=9.95e-01, error(valid)=9.27e-02, grads_output(valid)=1.21e-04, grads_weights(valid)=1.09e-03, grads_biases(valid)=6.69e-03, acc(valid)=9.76e-01
# Epoch 20: 1.5s to complete
#     error(train)=6.68e-03, grads_output(train)=2.22e-05, grads_weights(train)=8.30e-04, grads_biases(train)=8.35e-03, acc(train)=9.99e-01, error(valid)=8.04e-02, grads_output(valid)=9.87e-05, grads_weights(valid)=8.30e-04, grads_biases(valid)=8.35e-03, acc(valid)=9.80e-01
# Epoch 25: 1.5s to complete
#     error(train)=3.28e-03, grads_output(train)=1.22e-05, grads_weights(train)=3.75e-04, grads_biases(train)=2.81e-03, acc(train)=1.00e+00, error(valid)=8.36e-02, grads_output(valid)=9.64e-05, grads_weights(valid)=3.75e-04, grads_biases(valid)=2.81e-03, acc(valid)=9.79e-01
# Epoch 30: 1.5s to complete
#     error(train)=2.44e-03, grads_output(train)=9.29e-06, grads_weights(train)=3.41e-05, grads_biases(train)=1.89e-04, acc(train)=1.00e+00, error(valid)=8.44e-02, grads_output(valid)=9.33e-05, grads_weights(valid)=3.41e-05, grads_biases(valid)=1.89e-04, acc(valid)=9.81e-01
# Epoch 35: 1.5s to complete
#     error(train)=2.18e-03, grads_output(train)=8.45e-06, grads_weights(train)=4.12e-05, grads_biases(train)=2.49e-04, acc(train)=1.00e+00, error(valid)=8.60e-02, grads_output(valid)=9.56e-05, grads_weights(valid)=4.12e-05, grads_biases(valid)=2.49e-04, acc(valid)=9.80e-01
# Epoch 40: 1.5s to complete
#     error(train)=1.92e-03, grads_output(train)=7.46e-06, grads_weights(train)=3.46e-05, grads_biases(train)=1.89e-04, acc(train)=1.00e+00, error(valid)=8.43e-02, grads_output(valid)=9.28e-05, grads_weights(valid)=3.46e-05, grads_biases(valid)=1.89e-04, acc(valid)=9.80e-01
# Epoch 45: 1.5s to complete
#     error(train)=2.19e-03, grads_output(train)=8.44e-06, grads_weights(train)=2.74e-05, grads_biases(train)=1.10e-04, acc(train)=1.00e+00, error(valid)=8.53e-02, grads_output(valid)=9.25e-05, grads_weights(valid)=2.74e-05, grads_biases(valid)=1.10e-04, acc(valid)=9.80e-01
# Epoch 50: 1.5s to complete
#     error(train)=5.81e-03, grads_output(train)=1.93e-05, grads_weights(train)=1.18e-04, grads_biases(train)=6.41e-04, acc(train)=9.99e-01, error(valid)=9.20e-02, grads_output(valid)=9.96e-05, grads_weights(valid)=1.18e-04, grads_biases(valid)=6.41e-04, acc(valid)=9.78e-01
# Epoch 55: 1.5s to complete
#     error(train)=9.43e-03, grads_output(train)=2.62e-05, grads_weights(train)=1.22e-03, grads_biases(train)=8.88e-03, acc(train)=9.97e-01, error(valid)=9.77e-02, grads_output(valid)=1.03e-04, grads_weights(valid)=1.22e-03, grads_biases(valid)=8.88e-03, acc(valid)=9.78e-01
# Epoch 60: 1.5s to complete
#     error(train)=1.03e-03, grads_output(train)=4.04e-06, grads_weights(train)=4.93e-05, grads_biases(train)=3.60e-04, acc(train)=1.00e+00, error(valid)=8.62e-02, grads_output(valid)=8.80e-05, grads_weights(valid)=4.93e-05, grads_biases(valid)=3.60e-04, acc(valid)=9.81e-01
# Epoch 65: 1.5s to complete
#     error(train)=1.02e-03, grads_output(train)=4.01e-06, grads_weights(train)=7.46e-05, grads_biases(train)=7.58e-04, acc(train)=1.00e+00, error(valid)=8.48e-02, grads_output(valid)=8.86e-05, grads_weights(valid)=7.46e-05, grads_biases(valid)=7.58e-04, acc(valid)=9.81e-01
# Epoch 70: 1.5s to complete
#     error(train)=1.20e-03, grads_output(train)=4.74e-06, grads_weights(train)=4.52e-05, grads_biases(train)=2.74e-04, acc(train)=1.00e+00, error(valid)=8.32e-02, grads_output(valid)=8.98e-05, grads_weights(valid)=4.52e-05, grads_biases(valid)=2.74e-04, acc(valid)=9.81e-01
# Epoch 75: 1.5s to complete
#     error(train)=1.27e-03, grads_output(train)=5.02e-06, grads_weights(train)=9.26e-05, grads_biases(train)=5.00e-04, acc(train)=1.00e+00, error(valid)=8.23e-02, grads_output(valid)=9.07e-05, grads_weights(valid)=9.26e-05, grads_biases(valid)=5.00e-04, acc(valid)=9.81e-01
# Epoch 80: 1.5s to complete
#     error(train)=1.39e-03, grads_output(train)=5.49e-06, grads_weights(train)=2.37e-05, grads_biases(train)=1.13e-04, acc(train)=1.00e+00, error(valid)=8.22e-02, grads_output(valid)=9.12e-05, grads_weights(valid)=2.37e-05, grads_biases(valid)=1.13e-04, acc(valid)=9.81e-01
# Epoch 85: 1.5s to complete
#     error(train)=1.47e-03, grads_output(train)=5.80e-06, grads_weights(train)=6.64e-05, grads_biases(train)=3.14e-04, acc(train)=1.00e+00, error(valid)=8.22e-02, grads_output(valid)=9.34e-05, grads_weights(valid)=6.64e-05, grads_biases(valid)=3.14e-04, acc(valid)=9.80e-01
# Epoch 90: 1.5s to complete
#     error(train)=1.49e-03, grads_output(train)=5.85e-06, grads_weights(train)=3.95e-05, grads_biases(train)=2.21e-04, acc(train)=1.00e+00, error(valid)=8.23e-02, grads_output(valid)=9.34e-05, grads_weights(valid)=3.95e-05, grads_biases(valid)=2.21e-04, acc(valid)=9.80e-01
# Epoch 95: 1.5s to complete
#     error(train)=1.80e-02, grads_output(train)=4.40e-05, grads_weights(train)=5.97e-04, grads_biases(train)=3.68e-03, acc(train)=9.94e-01, error(valid)=1.08e-01, grads_output(valid)=1.22e-04, grads_weights(valid)=5.97e-04, grads_biases(valid)=3.68e-03, acc(valid)=9.74e-01
# Epoch 100: 1.5s to complete
#     error(train)=6.12e-03, grads_output(train)=1.74e-05, grads_weights(train)=1.72e-04, grads_biases(train)=9.99e-04, acc(train)=9.98e-01, error(valid)=9.91e-02, grads_output(valid)=9.75e-05, grads_weights(valid)=1.72e-04, grads_biases(valid)=9.99e-04, acc(valid)=9.78e-01
# Epoch 5: 1.5s to complete
#     error(train)=2.84e-01, grads_output(train)=5.95e-04, grads_weights(train)=2.34e-03, grads_biases(train)=8.27e-03, acc(train)=9.14e-01, error(valid)=2.70e-01, grads_output(valid)=5.62e-04, grads_weights(valid)=2.34e-03, grads_biases(valid)=8.27e-03, acc(valid)=9.21e-01
# Epoch 10: 1.4s to complete
#     error(train)=2.31e-01, grads_output(train)=4.69e-04, grads_weights(train)=2.09e-03, grads_biases(train)=8.03e-03, acc(train)=9.29e-01, error(valid)=2.15e-01, grads_output(valid)=4.35e-04, grads_weights(valid)=2.09e-03, grads_biases(valid)=8.03e-03, acc(valid)=9.32e-01
# Epoch 15: 1.5s to complete
#     error(train)=2.01e-01, grads_output(train)=4.16e-04, grads_weights(train)=2.01e-03, grads_biases(train)=4.87e-03, acc(train)=9.41e-01, error(valid)=1.92e-01, grads_output(valid)=3.94e-04, grads_weights(valid)=2.01e-03, grads_biases(valid)=4.87e-03, acc(valid)=9.42e-01
# Epoch 20: 1.4s to complete
#     error(train)=2.04e-01, grads_output(train)=4.32e-04, grads_weights(train)=2.05e-03, grads_biases(train)=7.95e-03, acc(train)=9.41e-01, error(valid)=1.96e-01, grads_output(valid)=4.09e-04, grads_weights(valid)=2.05e-03, grads_biases(valid)=7.95e-03, acc(valid)=9.42e-01
# Epoch 25: 1.4s to complete
#     error(train)=2.17e-01, grads_output(train)=4.51e-04, grads_weights(train)=1.81e-03, grads_biases(train)=4.60e-03, acc(train)=9.34e-01, error(valid)=2.13e-01, grads_output(valid)=4.23e-04, grads_weights(valid)=1.81e-03, grads_biases(valid)=4.60e-03, acc(valid)=9.36e-01
# Epoch 30: 1.4s to complete
#     error(train)=2.32e-01, grads_output(train)=4.58e-04, grads_weights(train)=1.70e-03, grads_biases(train)=4.78e-03, acc(train)=9.30e-01, error(valid)=2.25e-01, grads_output(valid)=4.34e-04, grads_weights(valid)=1.70e-03, grads_biases(valid)=4.78e-03, acc(valid)=9.31e-01
# Epoch 35: 1.4s to complete
#     error(train)=2.31e-01, grads_output(train)=4.70e-04, grads_weights(train)=2.36e-03, grads_biases(train)=7.77e-03, acc(train)=9.27e-01, error(valid)=2.36e-01, grads_output(valid)=4.56e-04, grads_weights(valid)=2.36e-03, grads_biases(valid)=7.77e-03, acc(valid)=9.28e-01
# Epoch 40: 1.4s to complete
#     error(train)=2.02e-01, grads_output(train)=4.10e-04, grads_weights(train)=2.32e-03, grads_biases(train)=8.44e-03, acc(train)=9.38e-01, error(valid)=1.94e-01, grads_output(valid)=3.83e-04, grads_weights(valid)=2.32e-03, grads_biases(valid)=8.44e-03, acc(valid)=9.40e-01
# Epoch 45: 1.4s to complete
#     error(train)=1.81e-01, grads_output(train)=3.72e-04, grads_weights(train)=1.74e-03, grads_biases(train)=3.98e-03, acc(train)=9.47e-01, error(valid)=1.79e-01, grads_output(valid)=3.59e-04, grads_weights(valid)=1.74e-03, grads_biases(valid)=3.98e-03, acc(valid)=9.46e-01
# Epoch 50: 1.4s to complete
#     error(train)=1.85e-01, grads_output(train)=3.94e-04, grads_weights(train)=1.33e-03, grads_biases(train)=2.14e-03, acc(train)=9.46e-01, error(valid)=1.89e-01, grads_output(valid)=3.81e-04, grads_weights(valid)=1.33e-03, grads_biases(valid)=2.14e-03, acc(valid)=9.46e-01
# Epoch 55: 1.5s to complete
#     error(train)=1.88e-01, grads_output(train)=3.90e-04, grads_weights(train)=2.51e-03, grads_biases(train)=1.05e-02, acc(train)=9.44e-01, error(valid)=1.90e-01, grads_output(valid)=3.72e-04, grads_weights(valid)=2.51e-03, grads_biases(valid)=1.05e-02, acc(valid)=9.45e-01
# Epoch 60: 1.4s to complete
#     error(train)=1.77e-01, grads_output(train)=3.59e-04, grads_weights(train)=1.62e-03, grads_biases(train)=4.70e-03, acc(train)=9.47e-01, error(valid)=1.77e-01, grads_output(valid)=3.48e-04, grads_weights(valid)=1.62e-03, grads_biases(valid)=4.70e-03, acc(valid)=9.45e-01
# Epoch 65: 1.4s to complete
#     error(train)=2.08e-01, grads_output(train)=4.40e-04, grads_weights(train)=1.64e-03, grads_biases(train)=3.56e-03, acc(train)=9.40e-01, error(valid)=1.99e-01, grads_output(valid)=4.12e-04, grads_weights(valid)=1.64e-03, grads_biases(valid)=3.56e-03, acc(valid)=9.42e-01
# Epoch 70: 1.4s to complete
#     error(train)=2.01e-01, grads_output(train)=4.11e-04, grads_weights(train)=1.86e-03, grads_biases(train)=6.40e-03, acc(train)=9.40e-01, error(valid)=2.00e-01, grads_output(valid)=3.90e-04, grads_weights(valid)=1.86e-03, grads_biases(valid)=6.40e-03, acc(valid)=9.40e-01
# Epoch 75: 1.4s to complete
#     error(train)=1.96e-01, grads_output(train)=3.93e-04, grads_weights(train)=1.79e-03, grads_biases(train)=4.78e-03, acc(train)=9.41e-01, error(valid)=1.91e-01, grads_output(valid)=3.71e-04, grads_weights(valid)=1.79e-03, grads_biases(valid)=4.78e-03, acc(valid)=9.44e-01
# Epoch 80: 1.4s to complete
#     error(train)=1.97e-01, grads_output(train)=3.95e-04, grads_weights(train)=1.23e-03, grads_biases(train)=1.26e-03, acc(train)=9.40e-01, error(valid)=1.95e-01, grads_output(valid)=3.73e-04, grads_weights(valid)=1.23e-03, grads_biases(valid)=1.26e-03, acc(valid)=9.43e-01
# Epoch 85: 1.4s to complete
#     error(train)=1.91e-01, grads_output(train)=4.06e-04, grads_weights(train)=1.56e-03, grads_biases(train)=3.56e-03, acc(train)=9.43e-01, error(valid)=1.93e-01, grads_output(valid)=3.91e-04, grads_weights(valid)=1.56e-03, grads_biases(valid)=3.56e-03, acc(valid)=9.44e-01
# Epoch 90: 1.5s to complete
#     error(train)=1.79e-01, grads_output(train)=3.68e-04, grads_weights(train)=1.55e-03, grads_biases(train)=3.41e-03, acc(train)=9.47e-01, error(valid)=1.80e-01, grads_output(valid)=3.51e-04, grads_weights(valid)=1.55e-03, grads_biases(valid)=3.41e-03, acc(valid)=9.49e-01
# Epoch 95: 1.4s to complete
#     error(train)=2.07e-01, grads_output(train)=4.21e-04, grads_weights(train)=2.08e-03, grads_biases(train)=5.97e-03, acc(train)=9.38e-01, error(valid)=2.07e-01, grads_output(valid)=4.03e-04, grads_weights(valid)=2.08e-03, grads_biases(valid)=5.97e-03, acc(valid)=9.40e-01
# Epoch 100: 1.4s to complete
#     error(train)=1.80e-01, grads_output(train)=3.77e-04, grads_weights(train)=2.51e-03, grads_biases(train)=7.39e-03, acc(train)=9.46e-01, error(valid)=1.78e-01, grads_output(valid)=3.59e-04, grads_weights(valid)=2.51e-03, grads_biases(valid)=7.39e-03, acc(valid)=9.47e-01
# Epoch 5: 1.4s to complete
#     error(train)=6.97e-02, grads_output(train)=1.61e-04, grads_weights(train)=1.70e-03, grads_biases(train)=8.36e-03, acc(train)=9.79e-01, error(valid)=1.02e-01, grads_output(valid)=1.87e-04, grads_weights(valid)=1.70e-03, grads_biases(valid)=8.36e-03, acc(valid)=9.71e-01
# Epoch 10: 1.4s to complete
#     error(train)=3.35e-02, grads_output(train)=8.46e-05, grads_weights(train)=1.19e-03, grads_biases(train)=1.01e-02, acc(train)=9.90e-01, error(valid)=8.49e-02, grads_output(valid)=1.34e-04, grads_weights(valid)=1.19e-03, grads_biases(valid)=1.01e-02, acc(valid)=9.77e-01
# Epoch 15: 1.3s to complete
#     error(train)=1.75e-02, grads_output(train)=4.95e-05, grads_weights(train)=9.11e-04, grads_biases(train)=7.30e-03, acc(train)=9.96e-01, error(valid)=9.13e-02, grads_output(valid)=1.21e-04, grads_weights(valid)=9.11e-04, grads_biases(valid)=7.30e-03, acc(valid)=9.76e-01
# Epoch 20: 1.4s to complete
#     error(train)=6.89e-03, grads_output(train)=2.32e-05, grads_weights(train)=3.23e-04, grads_biases(train)=2.65e-03, acc(train)=9.99e-01, error(valid)=8.00e-02, grads_output(valid)=1.03e-04, grads_weights(valid)=3.23e-04, grads_biases(valid)=2.65e-03, acc(valid)=9.79e-01
# Epoch 25: 1.4s to complete
#     error(train)=3.77e-03, grads_output(train)=1.41e-05, grads_weights(train)=3.17e-04, grads_biases(train)=2.46e-03, acc(train)=1.00e+00, error(valid)=8.32e-02, grads_output(valid)=9.90e-05, grads_weights(valid)=3.17e-04, grads_biases(valid)=2.46e-03, acc(valid)=9.79e-01
# Epoch 30: 1.4s to complete
#     error(train)=2.82e-03, grads_output(train)=1.08e-05, grads_weights(train)=1.94e-05, grads_biases(train)=1.22e-04, acc(train)=1.00e+00, error(valid)=8.23e-02, grads_output(valid)=9.72e-05, grads_weights(valid)=1.94e-05, grads_biases(valid)=1.22e-04, acc(valid)=9.80e-01
# Epoch 35: 1.4s to complete
#     error(train)=2.67e-03, grads_output(train)=1.03e-05, grads_weights(train)=7.98e-05, grads_biases(train)=5.46e-04, acc(train)=1.00e+00, error(valid)=8.38e-02, grads_output(valid)=9.96e-05, grads_weights(valid)=7.98e-05, grads_biases(valid)=5.46e-04, acc(valid)=9.79e-01
# Epoch 40: 1.4s to complete
#     error(train)=2.47e-03, grads_output(train)=9.57e-06, grads_weights(train)=3.47e-05, grads_biases(train)=2.31e-04, acc(train)=1.00e+00, error(valid)=8.16e-02, grads_output(valid)=9.66e-05, grads_weights(valid)=3.47e-05, grads_biases(valid)=2.31e-04, acc(valid)=9.79e-01
# Epoch 45: 1.4s to complete
#     error(train)=2.39e-03, grads_output(train)=9.30e-06, grads_weights(train)=4.23e-05, grads_biases(train)=2.39e-04, acc(train)=1.00e+00, error(valid)=8.14e-02, grads_output(valid)=9.58e-05, grads_weights(valid)=4.23e-05, grads_biases(valid)=2.39e-04, acc(valid)=9.80e-01
# Epoch 50: 1.4s to complete
#     error(train)=2.30e-03, grads_output(train)=8.96e-06, grads_weights(train)=5.35e-05, grads_biases(train)=2.82e-04, acc(train)=1.00e+00, error(valid)=8.16e-02, grads_output(valid)=9.67e-05, grads_weights(valid)=5.35e-05, grads_biases(valid)=2.82e-04, acc(valid)=9.80e-01
# Epoch 55: 1.3s to complete
#     error(train)=2.33e-03, grads_output(train)=9.07e-06, grads_weights(train)=3.51e-04, grads_biases(train)=2.28e-03, acc(train)=1.00e+00, error(valid)=8.18e-02, grads_output(valid)=9.68e-05, grads_weights(valid)=3.51e-04, grads_biases(valid)=2.28e-03, acc(valid)=9.80e-01
# Epoch 60: 1.5s to complete
#     error(train)=2.26e-03, grads_output(train)=8.82e-06, grads_weights(train)=7.96e-05, grads_biases(train)=5.73e-04, acc(train)=1.00e+00, error(valid)=8.09e-02, grads_output(valid)=9.78e-05, grads_weights(valid)=7.96e-05, grads_biases(valid)=5.73e-04, acc(valid)=9.79e-01
# Epoch 65: 1.4s to complete
#     error(train)=2.27e-03, grads_output(train)=8.89e-06, grads_weights(train)=1.20e-04, grads_biases(train)=1.10e-03, acc(train)=1.00e+00, error(valid)=8.10e-02, grads_output(valid)=9.80e-05, grads_weights(valid)=1.20e-04, grads_biases(valid)=1.10e-03, acc(valid)=9.80e-01
# Epoch 70: 1.3s to complete
#     error(train)=2.26e-03, grads_output(train)=8.86e-06, grads_weights(train)=8.44e-05, grads_biases(train)=5.25e-04, acc(train)=1.00e+00, error(valid)=8.00e-02, grads_output(valid)=9.80e-05, grads_weights(valid)=8.44e-05, grads_biases(valid)=5.25e-04, acc(valid)=9.80e-01
# Epoch 75: 1.3s to complete
#     error(train)=2.21e-03, grads_output(train)=8.64e-06, grads_weights(train)=1.10e-04, grads_biases(train)=7.82e-04, acc(train)=1.00e+00, error(valid)=7.89e-02, grads_output(valid)=9.74e-05, grads_weights(valid)=1.10e-04, grads_biases(valid)=7.82e-04, acc(valid)=9.80e-01
# Epoch 80: 1.4s to complete
#     error(train)=2.22e-03, grads_output(train)=8.68e-06, grads_weights(train)=2.14e-05, grads_biases(train)=1.42e-04, acc(train)=1.00e+00, error(valid)=7.99e-02, grads_output(valid)=9.83e-05, grads_weights(valid)=2.14e-05, grads_biases(valid)=1.42e-04, acc(valid)=9.80e-01
# Epoch 85: 1.3s to complete
#     error(train)=2.27e-03, grads_output(train)=8.91e-06, grads_weights(train)=8.04e-05, grads_biases(train)=3.51e-04, acc(train)=1.00e+00, error(valid)=7.91e-02, grads_output(valid)=9.93e-05, grads_weights(valid)=8.04e-05, grads_biases(valid)=3.51e-04, acc(valid)=9.80e-01
# Epoch 90: 1.3s to complete
#     error(train)=2.21e-03, grads_output(train)=8.66e-06, grads_weights(train)=5.71e-05, grads_biases(train)=3.75e-04, acc(train)=1.00e+00, error(valid)=7.94e-02, grads_output(valid)=9.88e-05, grads_weights(valid)=5.71e-05, grads_biases(valid)=3.75e-04, acc(valid)=9.79e-01
# Epoch 95: 1.3s to complete
#     error(train)=2.15e-03, grads_output(train)=8.42e-06, grads_weights(train)=2.23e-04, grads_biases(train)=1.28e-03, acc(train)=1.00e+00, error(valid)=7.87e-02, grads_output(valid)=9.77e-05, grads_weights(valid)=2.23e-04, grads_biases(valid)=1.28e-03, acc(valid)=9.80e-01
# Epoch 100: 1.4s to complete
#     error(train)=2.15e-03, grads_output(train)=8.45e-06, grads_weights(train)=1.49e-04, grads_biases(train)=1.03e-03, acc(train)=1.00e+00, error(valid)=7.82e-02, grads_output(valid)=9.82e-05, grads_weights(valid)=1.49e-04, grads_biases(valid)=1.03e-03, acc(valid)=9.80e-01
# Epoch 5: 1.3s to complete
#     error(train)=2.39e-01, grads_output(train)=5.87e-04, grads_weights(train)=1.45e-03, grads_biases(train)=7.09e-03, acc(train)=9.37e-01, error(valid)=2.28e-01, grads_output(valid)=5.53e-04, grads_weights(valid)=1.45e-03, grads_biases(valid)=7.09e-03, acc(valid)=9.44e-01
# Epoch 10: 1.4s to complete
#     error(train)=2.19e-01, grads_output(train)=5.45e-04, grads_weights(train)=1.67e-03, grads_biases(train)=8.20e-03, acc(train)=9.44e-01, error(valid)=2.05e-01, grads_output(valid)=5.07e-04, grads_weights(valid)=1.67e-03, grads_biases(valid)=8.20e-03, acc(valid)=9.49e-01
# Epoch 15: 1.3s to complete
#     error(train)=2.09e-01, grads_output(train)=5.32e-04, grads_weights(train)=1.31e-03, grads_biases(train)=4.92e-03, acc(train)=9.48e-01, error(valid)=1.98e-01, grads_output(valid)=4.95e-04, grads_weights(valid)=1.31e-03, grads_biases(valid)=4.92e-03, acc(valid)=9.53e-01
# Epoch 20: 1.3s to complete
#     error(train)=2.19e-01, grads_output(train)=5.63e-04, grads_weights(train)=1.24e-03, grads_biases(train)=7.34e-03, acc(train)=9.48e-01, error(valid)=2.05e-01, grads_output(valid)=5.25e-04, grads_weights(valid)=1.24e-03, grads_biases(valid)=7.34e-03, acc(valid)=9.52e-01
# Epoch 25: 1.3s to complete
#     error(train)=2.13e-01, grads_output(train)=5.38e-04, grads_weights(train)=1.37e-03, grads_biases(train)=9.28e-03, acc(train)=9.45e-01, error(valid)=2.01e-01, grads_output(valid)=5.02e-04, grads_weights(valid)=1.37e-03, grads_biases(valid)=9.28e-03, acc(valid)=9.49e-01
# Epoch 30: 1.3s to complete
#     error(train)=2.12e-01, grads_output(train)=5.40e-04, grads_weights(train)=8.22e-04, grads_biases(train)=4.50e-03, acc(train)=9.47e-01, error(valid)=2.00e-01, grads_output(valid)=5.05e-04, grads_weights(valid)=8.22e-04, grads_biases(valid)=4.50e-03, acc(valid)=9.50e-01
# Epoch 35: 1.3s to complete
#     error(train)=2.09e-01, grads_output(train)=5.38e-04, grads_weights(train)=1.27e-03, grads_biases(train)=6.50e-03, acc(train)=9.48e-01, error(valid)=1.99e-01, grads_output(valid)=5.04e-04, grads_weights(valid)=1.27e-03, grads_biases(valid)=6.50e-03, acc(valid)=9.53e-01
# Epoch 40: 1.3s to complete
#     error(train)=2.20e-01, grads_output(train)=5.55e-04, grads_weights(train)=1.01e-03, grads_biases(train)=5.01e-03, acc(train)=9.45e-01, error(valid)=2.05e-01, grads_output(valid)=5.13e-04, grads_weights(valid)=1.01e-03, grads_biases(valid)=5.01e-03, acc(valid)=9.51e-01
# Epoch 45: 1.3s to complete
#     error(train)=2.07e-01, grads_output(train)=5.19e-04, grads_weights(train)=1.32e-03, grads_biases(train)=5.89e-03, acc(train)=9.47e-01, error(valid)=1.94e-01, grads_output(valid)=4.81e-04, grads_weights(valid)=1.32e-03, grads_biases(valid)=5.89e-03, acc(valid)=9.50e-01
# Epoch 50: 1.3s to complete
#     error(train)=2.03e-01, grads_output(train)=5.24e-04, grads_weights(train)=9.51e-04, grads_biases(train)=4.09e-03, acc(train)=9.51e-01, error(valid)=1.93e-01, grads_output(valid)=4.90e-04, grads_weights(valid)=9.51e-04, grads_biases(valid)=4.09e-03, acc(valid)=9.55e-01
# Epoch 55: 1.3s to complete
#     error(train)=2.04e-01, grads_output(train)=5.21e-04, grads_weights(train)=1.94e-03, grads_biases(train)=1.15e-02, acc(train)=9.49e-01, error(valid)=1.94e-01, grads_output(valid)=4.86e-04, grads_weights(valid)=1.94e-03, grads_biases(valid)=1.15e-02, acc(valid)=9.53e-01
# Epoch 60: 1.3s to complete
#     error(train)=1.97e-01, grads_output(train)=5.03e-04, grads_weights(train)=1.14e-03, grads_biases(train)=7.00e-03, acc(train)=9.52e-01, error(valid)=1.86e-01, grads_output(valid)=4.69e-04, grads_weights(valid)=1.14e-03, grads_biases(valid)=7.00e-03, acc(valid)=9.56e-01
# Epoch 65: 1.3s to complete
#     error(train)=2.07e-01, grads_output(train)=5.40e-04, grads_weights(train)=1.07e-03, grads_biases(train)=5.03e-03, acc(train)=9.51e-01, error(valid)=1.97e-01, grads_output(valid)=5.06e-04, grads_weights(valid)=1.07e-03, grads_biases(valid)=5.03e-03, acc(valid)=9.53e-01
# Epoch 70: 1.4s to complete
#     error(train)=2.02e-01, grads_output(train)=5.20e-04, grads_weights(train)=7.87e-04, grads_biases(train)=3.62e-03, acc(train)=9.51e-01, error(valid)=1.91e-01, grads_output(valid)=4.84e-04, grads_weights(valid)=7.87e-04, grads_biases(valid)=3.62e-03, acc(valid)=9.55e-01
# Epoch 75: 1.3s to complete
#     error(train)=2.06e-01, grads_output(train)=5.25e-04, grads_weights(train)=1.11e-03, grads_biases(train)=5.87e-03, acc(train)=9.50e-01, error(valid)=1.93e-01, grads_output(valid)=4.87e-04, grads_weights(valid)=1.11e-03, grads_biases(valid)=5.87e-03, acc(valid)=9.53e-01
# Epoch 80: 1.3s to complete
#     error(train)=2.04e-01, grads_output(train)=5.17e-04, grads_weights(train)=5.98e-04, grads_biases(train)=2.47e-03, acc(train)=9.48e-01, error(valid)=1.92e-01, grads_output(valid)=4.77e-04, grads_weights(valid)=5.98e-04, grads_biases(valid)=2.47e-03, acc(valid)=9.53e-01
# Epoch 85: 1.3s to complete
#     error(train)=2.06e-01, grads_output(train)=5.26e-04, grads_weights(train)=9.33e-04, grads_biases(train)=3.90e-03, acc(train)=9.49e-01, error(valid)=1.95e-01, grads_output(valid)=4.89e-04, grads_weights(valid)=9.33e-04, grads_biases(valid)=3.90e-03, acc(valid)=9.52e-01
# Epoch 90: 1.3s to complete
#     error(train)=2.14e-01, grads_output(train)=5.38e-04, grads_weights(train)=8.52e-04, grads_biases(train)=4.23e-03, acc(train)=9.45e-01, error(valid)=2.04e-01, grads_output(valid)=5.04e-04, grads_weights(valid)=8.52e-04, grads_biases(valid)=4.23e-03, acc(valid)=9.51e-01
# Epoch 95: 1.3s to complete
#     error(train)=2.02e-01, grads_output(train)=5.27e-04, grads_weights(train)=1.28e-03, grads_biases(train)=6.57e-03, acc(train)=9.52e-01, error(valid)=1.91e-01, grads_output(valid)=4.91e-04, grads_weights(valid)=1.28e-03, grads_biases(valid)=6.57e-03, acc(valid)=9.56e-01
# Epoch 100: 1.3s to complete
#     error(train)=2.04e-01, grads_output(train)=5.17e-04, grads_weights(train)=1.93e-03, grads_biases(train)=8.79e-03, acc(train)=9.49e-01, error(valid)=1.93e-01, grads_output(valid)=4.83e-04, grads_weights(valid)=1.93e-03, grads_biases(valid)=8.79e-03, acc(valid)=9.52e-01

# %% [markdown]
# ---
# **Notes**
#
# Looking at the results, we get the best results for small regularisation coefficent (and particularly L2).
#
# A small regularisation coefficient improves performance on the validation set by mitigating overfitting issues.
#
# A large regularisation coefficient tends to cause the model to underfit, characterised by increased error on both the training and validation set compared to the no regularisation error. The training and validation errors become similar in value, which _I think_ can be interpreted as another sign of underfitting (or more precisely as a sign of minimal overfitting).
#
# ---

# %% [markdown]
# The cell below defines two functions for visualising the first layer weights of the models trained above. The first plots a histogram of the weight values and the second plots the first layer weights as feature maps, i.e. each row of the first layer weight matrix (corresponding to the weights going from the input MNIST image to a particular first layer output) is visualised as a $28\times 28$ image. In these feature maps white corresponds to negative weights, black to positive weights and grey to weights close to zero.
#
# Use these functions to plot a histogram and feature map visualisation for the first layer weights of each model trained above. You should try to interpret the plots in the context of what you were told in the lecture about the behaviour of L1 versus L2 regularisation.

# %%
def plot_param_histogram(param, fig_size=(6, 3), interval=[-1.5, 1.5]):
    """Plots a normalised histogram of an array of parameter values."""
    fig = plt.figure(figsize=fig_size)
    ax = fig.add_subplot(111)
    ax.hist(param.flatten(), 50, interval, density=True)
    ax.set_xlabel('Parameter value')
    ax.set_ylabel('Normalised frequency density')
    return fig, ax

def visualise_first_layer_weights(weights, fig_size=(5, 5)):
    """Plots a grid of first layer weights as feature maps."""
    fig = plt.figure(figsize=fig_size)
    num_feature_maps = weights.shape[0]
    grid_size = int(num_feature_maps**0.5)
    max_abs = np.abs(model.params[0]).max()
    tiled = -np.ones((30 * grid_size, 
                      30 * num_feature_maps // grid_size)) * max_abs
    for i, fm in enumerate(model.params[0]):
        r, c = i % grid_size, i // grid_size
        tiled[1 + r * 30:(r + 1) * 30 - 1, 
              1 + c * 30:(c + 1) * 30 - 1] = fm.reshape((28, 28))
    ax = fig.add_subplot(111)
    max_abs = np.abs(tiled).max()
    ax.imshow(tiled, cmap='Greys', vmin=-max_abs, vmax=max_abs)
    ax.axis('off')
    fig.tight_layout()
    plt.show()
    return fig, ax

# %%
for model, params in zip(Models, Params):
    print(str(params))
    plot_param_histogram(model.params[0])
    visualise_first_layer_weights(model.params[0])
# Out:
# {'regularisation': 'None', 'alpha': None}
# {'regularisation': 'l1', 'alpha': 1e-05}
# {'regularisation': 'l1', 'alpha': 0.001}
# {'regularisation': 'l2', 'alpha': 0.0001}
# {'regularisation': 'l2', 'alpha': 0.01}

# %%
import pandas as pd

for model, params in zip(Models, Params):
    print(str(params))
    biases = model.params[1].reshape((10,10))
    biases = biases.T
    assert model.params[1][10] == biases[0,1]
    print(pd.DataFrame(biases))
# Out:
# {'regularisation': 'None', 'alpha': None}
#           0         1         2         3         4         5         6  \
# 0 -0.082735 -0.122350 -0.023872 -0.175325 -0.295189  0.145194  0.174191
# 1 -0.102441  0.104115  0.045040 -0.062640  0.200805  0.127274  0.014072
# 2 -0.066817 -0.000711  0.057798  0.045163  0.026036  0.060489  0.182457
# 3 -0.041427 -0.008087  0.126280  0.022894 -0.104206  0.037626  0.003700
# 4  0.017007 -0.036389  0.107497  0.082853 -0.066637  0.022426 -0.149520
# 5  0.262984 -0.030218  0.018369  0.048947  0.125832 -0.035103  0.140653
# 6  0.069459  0.208271 -0.053820 -0.014369 -0.037503  0.243611  0.117599
# 7  0.081385 -0.059830  0.109649 -0.215912  0.165688 -0.058667  0.102071
# 8 -0.022454 -0.000031  0.109166  0.052033  0.000145  0.167636 -0.004557
# 9 -0.166950  0.144818 -0.082282 -0.183354  0.103211  0.041323  0.154713
#
#           7         8         9
# 0  0.100829  0.083033  0.016250
# 1  0.094779  0.069820 -0.062552
# 2 -0.073268  0.007985 -0.048095
# 3  0.051056  0.111577  0.109546
# 4 -0.062837  0.135578  0.141786
# 5  0.074406  0.307103  0.177099
# 6  0.098862  0.040255  0.032073
# 7  0.221486  0.189137  0.059741
# 8 -0.009562 -0.016511 -0.048956
# 9  0.023364  0.080718 -0.217675
# {'regularisation': 'l1', 'alpha': 1e-05}
#           0         1         2         3         4         5         6  \
# 0 -0.074413 -0.102848 -0.075693 -0.218943 -0.311759  0.164691  0.183088
# 1 -0.170211  0.025476  0.151910 -0.156971  0.256062  0.063180  0.045081
# 2 -0.082259  0.017702  0.022472  0.056364 -0.039647  0.013864  0.133372
# 3 -0.167801  0.006067  0.154470 -0.032601 -0.087858  0.068731  0.032435
# 4 -0.005098 -0.084959  0.344811  0.184879 -0.059963 -0.013490 -0.227971
# 5  0.236328 -0.086565  0.139846  0.130688  0.131278 -0.051355  0.175517
# 6  0.101984  0.214350 -0.066128 -0.031079 -0.194233  0.164885  0.112617
# 7  0.086010 -0.098674  0.120344 -0.412508  0.187818  0.141811  0.110086
# 8 -0.111077 -0.000025  0.203944 -0.020296  0.077414  0.212403  0.093377
# 9 -0.213149  0.068394 -0.201067 -0.304388  0.189554  0.020697  0.217398
#
#           7         8         9
# 0  0.123487  0.215247 -0.001771
# 1  0.207964  0.075043 -0.161692
# 2 -0.062217  0.017969  0.005797
# 3 -0.047141  0.193006  0.093419
# 4 -0.031705  0.248830  0.185833
# 5 -0.055331  0.516108  0.226410
# 6  0.191280 -0.048395  0.091720
# 7  0.178956  0.149620  0.045856
# 8  0.036414  0.024978  0.076818
# 9  0.047471 -0.011877 -0.240290
# {'regularisation': 'l1', 'alpha': 0.001}
#           0         1         2         3         4         5         6  \
# 0  0.002346 -0.029312  0.011465  0.015528  0.015007  0.015689  0.657814
# 1  0.015991  0.015996  0.002004  0.139307  0.016298  0.015681  0.015419
# 2  0.015061  0.571865  0.015891  0.015629  0.015548 -0.003746  0.016053
# 3  0.015820  0.015452 -0.002478  0.011182  0.015637 -0.009587  0.708995
# 4  0.015695 -0.035756  0.014957  0.015532  0.167010 -0.015259  0.084244
# 5  0.015913  0.005214  0.222023  0.012152 -0.008392 -0.054046  0.015758
# 6  0.015656  1.181864  0.015654  0.015561  0.015998  1.361869 -0.002025
# 7 -0.013252  0.008669  0.015725  0.015885  0.016197 -0.002362  0.016582
# 8 -0.169676 -0.000938  0.015775  0.016054 -0.010537 -0.015517  0.006017
# 9  0.017202  0.015651  0.002995  0.016515  0.015414  0.015646  0.015196
#
#           7         8         9
# 0  0.008435  0.015933 -0.002358
# 1 -0.003016  0.015528  0.016675
# 2 -0.003480  0.014781  1.008920
# 3  0.004552  0.015568  0.015275
# 4 -0.000869  0.015559  0.015834
# 5  0.016166  0.016600 -0.000892
# 6  0.015347  0.015081 -0.002276
# 7  0.848748  0.015959  0.010952
# 8 -0.026906  0.015830  0.304565
# 9 -0.001429  0.015190  0.403553
# {'regularisation': 'l2', 'alpha': 0.0001}
#           0         1         2         3         4         5         6  \
# 0 -0.116646 -0.158130  0.013980 -0.181130 -0.250324  0.140963  0.239506
# 1 -0.165294  0.116492  0.152122 -0.148851  0.225497  0.184708  0.081171
# 2 -0.042246 -0.007448  0.039985  0.025166  0.037006  0.003407  0.157151
# 3 -0.042596 -0.014781  0.107862 -0.017615 -0.086252  0.098401  0.013946
# 4  0.037138 -0.046862  0.204810  0.074201 -0.020227  0.004097 -0.126744
# 5  0.233858 -0.044213  0.027954  0.106903  0.179947 -0.024012  0.122660
# 6  0.072467  0.242219 -0.072147  0.034760 -0.136114  0.234833  0.116525
# 7  0.111274 -0.124848  0.082606 -0.341655  0.189806  0.039471  0.153598
# 8 -0.102117 -0.000590  0.229274  0.040038  0.113475  0.207609  0.084330
# 9 -0.161770  0.102054 -0.134437 -0.245649  0.168431  0.037191  0.218709
#
#           7         8         9
# 0  0.126862  0.062593  0.041710
# 1  0.151554  0.072778 -0.119480
# 2 -0.056486  0.049950 -0.018056
# 3  0.107325  0.153864  0.060412
# 4 -0.094204  0.277920  0.183028
# 5  0.077396  0.409582  0.217980
# 6  0.204331 -0.015392  0.209936
# 7  0.267945  0.229691  0.107207
# 8  0.002171  0.021326  0.029828
# 9  0.102436  0.137551 -0.162084
# {'regularisation': 'l2', 'alpha': 0.01}
#           0         1         2         3         4         5         6  \
# 0  0.077671 -0.011346  0.246622  0.315178  0.142476  0.168829  0.442370
# 1  0.660129  0.257760  0.056963  0.538761  0.206094  0.040401  0.477912
# 2  0.017837  0.358628  0.574847  0.745079 -0.087382  0.322773  0.217951
# 3  0.006856  0.197004  0.005102  0.026329  0.060096 -0.032643  1.124724
# 4  0.084716 -0.020003  0.265545  0.215031 -0.296018 -0.013215  0.281847
# 5  0.565494  0.101159  0.228034  0.364218  0.195548  0.030698  1.125904
# 6  0.144505  0.376991  0.264532 -0.102518  0.644551  0.443897  0.094872
# 7  0.213947 -0.010672  0.221924  0.229205  0.489189  0.088714  0.168149
# 8  0.225048 -0.001584  0.130266  0.156610  0.296692  0.097074  0.214133
# 9  0.006373  0.810116  0.130933  0.569662  0.027375 -0.247261  0.045210
#
#           7         8         9
# 0  0.256730  0.247398 -0.002203
# 1  0.060884  0.134865  0.095530
# 2  0.008832 -0.042883  0.268366
# 3  0.083050  0.655118  0.434719
# 4  0.225175  0.366614  0.018473
# 5  0.171203  0.878467  0.094094
# 6  0.382682  0.354416  0.478323
# 7  0.419117  1.430177  0.219385
# 8  0.059223  0.698064  0.053755
# 9 -0.044068  0.347096  0.098147

# %% [markdown]
# ---
#
# **Notes**
#
# **Feature map**: We visualise the trained first layer weights, of dimension [784 x 100] = [28x28] x [10x10], i.e. there are 100 sets of 784 weights, each set is associated to a single output and therefore a single hidden unit. The squares represent the weights associated with each output. Each square is a 28x28 map representing the values of the weights associated with each pixel. Color scheme is experessed as black: positive, white: negative, gray: zero.
#
# **Regularisation effect**
#
# Both regularisation schemes penalise large values of the weights, leading them to appear in smaller proportions, as observed on the histograms.
#
# Interrestingly, the interplay between the data and regularisation objectives lead to weights associated with specific regions of the image to be reduced, as observed on the feature maps. Weights learning features at the image edges are the first to disappear. This is desirable as in MNIST there is usually no information relevant to the classes on the edges, so non-zero weights there would correspond to overfitting.
#
# We could say that L1 and L2 regularisation is akin to performing a "low-pass filtering" of the weights. Small regularisation coefficients denoise the feature maps, and large ones make them blurry / make features disappear altogether. However, this is more advanced than simple low-pass filtering, since, as we observed above, the filtering is more or less intense at different regions of the image.
#
# We can also observe that some of the hidden units have completely blank maps, meaning that they end up either not being used, or being used a simply biases units. (I checked, a blank feature map does not necessarily correspond to 0 associated bias at the output unit). Accross regularisation experiments the same hidden units end up blank, although this might not be surprising since all experiments use the exact same initialisations, and training conditions (e.g. sampling order of the training set), thanks to the seed reset.
#
# **L2 Regularisation**
#
# L2 regularisation penalises the square value of the weights, meaning large weights are harshly penalised and will tend to disapear first, as seen in the histograms.
#
# _High coefficient value_: Large weights have completely disappeared, leaving the feature maps "blurry". Interestingly nearly all of the output layers are still used compared to high-L1, but the performance of the two are similar.
#
# _Low coefficient value_: Almost all outputs have non-uniform feature maps, meaning the model's capacity is exploited well. This feature map is the most similar to the unregularised one, and looks like a "denoised" version of it.
#
# **L1 Regularisation**
#
# L1 regularisation penalises the absolute value of the weights, it does not penalise large weights as harshly as L2 regularisation, and we see that for reasonable regularisation coefficients, more large weight values remain. It penalises small weights (<1) more harshly than L2 however, and we see that we obtain sparse weights, especially with a high regularisation coefficient.
#
# _High coefficient value_: Almost all weights are close to 0 and observing the feature map show that nearly all the hidden units have uniform and 0 weights, meaning the model's capacity is vastly underutilised, a sign of underfitting.
#
# As previously mentioned, this model still achieves similar performance to high-L2, even though the latter as more expressive feature maps. This would indicate that reasonable performance (albeit not optimal) can be achieved by a model relying on a simple/sparse combination (sparse output) of a few features (feature maps that are not uniform only have a few regions of non-zero weights)
#
# _Low coefficient value_: Almost all outputs have non-uniform feature maps, meaning the model's capacity is exploited well. The plots appear slightly "blurry" compared to the original and good L2 map, as there is a higher density of 0 weights.
#
#
# ---

# %% [markdown]
# ## Exercise 3: Random data augmentation
#
# Another technique mentioned in the lectures for trying to reduce overfitting is to artificially augment the training data set by performing random transformations to the original training data inputs. The idea is to produce further artificial inputs corresponding to the same target class as the original input. The closer the artificially generated inputs are appearing like the true inputs the better, as they provide more realistic additional examples for the model to learn from.
#
# For the handwritten image inputs in the MNIST dataset, an obvious way to considering augmenting the dataset is to apply small rotations to the original images. Providing the rotations are small we would generally expect that what we would identify as the class of a digit image will remain the same.
#
# Implement a function which given a batch of MNIST images as 784-dimensional vectors, i.e. an array of shape `(batch_size, 784)`
#
#   * chooses 25% of the images in the batch at random
#   * for each image in the 25% chosen, rotates the image by a random angle in $\left[-30^\circ,\,30^\circ\right]$
#   * returns a new array of size `(batch_size, 784)` in which the rows corresponding to the 25% chosen images are the vectors corresponding to the new randomly rotated images, while the remaining rows correspond to the original images.
#
# You will need to make use of the [`scipy.ndimage.interpolation.rotate`](https://docs.scipy.org/doc/scipy-0.16.0/reference/generated/scipy.ndimage.interpolation.rotate.html#scipy.ndimage.interpolation.rotate) function which is imported below for you. For computational efficiency you should use bilinear interpolation by setting `order=1` as a keyword argument to this function rather than using the default of bicubic interpolation. Additionally you should make sure the original shape of the images is maintained by passing a `reshape=False` keyword argument.

# %%
from scipy.ndimage.interpolation import rotate
from scipy.stats import bernoulli
import copy

def random_rotation(inputs, rng):
    """Randomly rotates a subset of images in a batch.
    
    Args:
        inputs: Input image batch, an array of shape (batch_size, 784).
        rng: A seeded random number generator.
        
    Returns:
        An array of shape (batch_size, 784) corresponding to a copy
        of the original `inputs` array with the randomly selected
        images rotated by a random angle. The original `inputs`
        array should not be modified.
    """

    #rotation angle range in degrees
    angle_range = 30

    img_dimension = int(inputs.shape[1]**0.5)
    # ensure the image is square.
    assert img_dimension**2 == inputs.shape[1]

    # random boolean mask to select which inputs to augment.
    n_augmented = inputs.shape[0] // 4
    mask = np.concatenate((np.ones(n_augmented), np.zeros(inputs.shape[0]-n_augmented)))
    rng.shuffle(mask)

    angles = rng.uniform(-angle_range, angle_range, n_augmented)

    augmented_inputs = copy.deepcopy(inputs)

    for ind, angle in zip(np.flatnonzero(mask), angles):
        image = augmented_inputs[ind].reshape((img_dimension, img_dimension))
        rotated_image = rotate(image, angle=angle, order=1, reshape=False)
        augmented_inputs[ind] = rotated_image.flatten()

    return augmented_inputs

# %% [markdown]
# Use the cell below to test your implementation. This uses the `show_batch_of_images` function we implemented in the first lab notebook to visualise the images in a batch before and after application of the random rotation transformation.

# %%
from mlp.data_providers import MNISTDataProvider
import matplotlib.pyplot as plt
def show_batch_of_images(img_batch, fig_size=(3, 3)):
    fig = plt.figure(figsize=fig_size)
    batch_size, im_height, im_width = img_batch.shape
    # calculate no. columns per grid row to give square grid
    grid_size = int(batch_size**0.5)
    # intialise empty array to tile image grid into
    tiled = np.empty((im_height * grid_size, 
                      im_width * batch_size // grid_size))
    # iterate over images in batch + indexes within batch
    for i, img in enumerate(img_batch):
        # calculate grid row and column indices
        r, c = i % grid_size, i // grid_size
        tiled[r * im_height:(r + 1) * im_height, 
              c * im_height:(c + 1) * im_height] = img
    ax = fig.add_subplot(111)
    ax.imshow(tiled, cmap='Greys') #, vmin=0., vmax=1.)
    ax.axis('off')
    fig.tight_layout()
    plt.show()
    return fig, ax

test_data = MNISTDataProvider('test', 100, rng=rng)
inputs, targets = test_data.next()
_ = show_batch_of_images(inputs.reshape((-1, 28, 28)))
transformed_inputs = random_rotation(inputs, rng)
_ = show_batch_of_images(transformed_inputs.reshape((-1, 28, 28)))

# %% [markdown]
# ## Exercise 4: Training with data augmentation
#
# One simple way to use data augmentation is to just statically augment the training data set - for example we could iterate through the training dataset applying a transformation function like that implemented above to generate new artificial inputs, and use both the original and newly generated data in a new data provider object. We are quite limited however in how far we can augment the dataset by with a static method like this however - if we wanted to apply 9 random rotations to each image in the original datase, we would end up with a dataset with 10 times the memory requirements and that would take 10 times as long to run through each epoch.
#
# An alternative is to randomly augment the data on the fly as we iterate through the data provider in each epoch. In this method a new data provider class can be defined that inherits from the original data provider to be augmented, and provides a new `next` method which applies a random transformation function like that implemented in the previous exercise to each input batch before returning it. This method means that on every epoch a different set of training examples are provided to the model and so in some ways corresponds to an 'infinite' data set (although the amount of variability in the dataset will still be significantly less than the variability in all possible digit images). Compared to static augmentation, this dynamic augmentation scheme comes at the computational cost of having to apply the random transformation each time a new batch is provided. We can vary this overhead by changing the proportion of images in a batch randomly transformed.
#
# An implementation of this scheme has been provided for the MNIST data set in the `AugmentedMNISTDataProvider` object in the `mlp.data_providers` module. In addition to the arguments of the original `MNISTDataProvider.__init__` method, this additional takes a `transformer` argument, which should be a function which takes as arguments an inputs batch array and a random number generator object, and returns an array corresponding to a random transformation of the inputs.
#
# Train a model with the same architecture as in exercise 3 and with no L1 / L2 regularisation using a training data provider which randomly augments the training images using your `random_rotation` transformer function. Plot the training and validation set errors over the training epochs and compare this plot to your previous results from exercise 3.

# %%
from mlp.data_providers import AugmentedMNISTDataProvider

# Reset random number generator and data provider states
# to ensure reproducibility of results
rng.seed(seed)
aug_train_data = AugmentedMNISTDataProvider('train', rng=rng, transformer=random_rotation)
valid_data.reset()

# Parameters constant accross runs
# Set training run hyperparameters
batch_size = 50  # number of data points in a batch
learning_rate = 0.01  # learning rate for gradient descent
num_epochs = 100  # number of training epochs to perform
stats_interval = 5  # epoch interval between recording and printing stats
input_dim, output_dim, hidden_dim = 784, 10, 100
weights_penalty = None
reg_scheme = 'augmented_data'

params = {'regularisation': reg_scheme,
}

assert num_epochs >= stats_interval

# Create a parameter initialiser
weights_init = GlorotUniformInit(0.5, rng)
biases_init = ConstantInit(0.)
# Initialise the error object
error = CrossEntropySoftmaxError()
# Use Momentum learning rule
learning_rule = MomentumLearningRule(learning_rate=learning_rate)

# Alter data-provider batch size
aug_train_data.batch_size = batch_size
valid_data.batch_size = batch_size

model = initialise_model(input_dim, hidden_dim, weights_init, biases_init, weights_penalty)

stats, keys, model, figs, axs = train_model_and_plot_stats(
model, error, learning_rule, aug_train_data, valid_data, num_epochs, stats_interval, params)
Stats.append(stats)
Models.append(model)
Params.append(params)

fig_train, ax_train, fig_valid, ax_valid = plot_all_errors(Stats, Params)
# Out:
# Epoch 5: 2.4s to complete
#     error(train)=9.99e-02, grads_output(train)=2.15e-04, grads_weights(train)=4.91e-04, grads_biases(train)=3.53e-03, acc(train)=9.71e-01, error(valid)=9.67e-02, grads_output(valid)=1.89e-04, grads_weights(valid)=4.91e-04, grads_biases(valid)=3.53e-03, acc(valid)=9.71e-01
# Epoch 10: 2.4s to complete
#     error(train)=5.64e-02, grads_output(train)=1.18e-04, grads_weights(train)=1.41e-03, grads_biases(train)=7.41e-03, acc(train)=9.83e-01, error(valid)=7.41e-02, grads_output(valid)=1.23e-04, grads_weights(valid)=1.41e-03, grads_biases(valid)=7.41e-03, acc(valid)=9.78e-01
# Epoch 15: 2.4s to complete
#     error(train)=4.82e-02, grads_output(train)=9.79e-05, grads_weights(train)=3.67e-04, grads_biases(train)=3.10e-03, acc(train)=9.86e-01, error(valid)=7.42e-02, grads_output(valid)=1.14e-04, grads_weights(valid)=3.67e-04, grads_biases(valid)=3.10e-03, acc(valid)=9.79e-01
# Epoch 20: 2.3s to complete
#     error(train)=3.82e-02, grads_output(train)=7.75e-05, grads_weights(train)=7.07e-04, grads_biases(train)=8.38e-03, acc(train)=9.89e-01, error(valid)=7.65e-02, grads_output(valid)=1.09e-04, grads_weights(valid)=7.07e-04, grads_biases(valid)=8.38e-03, acc(valid)=9.79e-01
# Epoch 25: 2.3s to complete
#     error(train)=3.04e-02, grads_output(train)=5.98e-05, grads_weights(train)=5.14e-04, grads_biases(train)=6.95e-03, acc(train)=9.92e-01, error(valid)=6.75e-02, grads_output(valid)=9.58e-05, grads_weights(valid)=5.14e-04, grads_biases(valid)=6.95e-03, acc(valid)=9.81e-01
# Epoch 30: 2.3s to complete
#     error(train)=2.63e-02, grads_output(train)=5.43e-05, grads_weights(train)=4.80e-04, grads_biases(train)=3.92e-03, acc(train)=9.92e-01, error(valid)=7.21e-02, grads_output(valid)=9.70e-05, grads_weights(valid)=4.80e-04, grads_biases(valid)=3.92e-03, acc(valid)=9.80e-01
# Epoch 35: 2.4s to complete
#     error(train)=2.93e-02, grads_output(train)=5.86e-05, grads_weights(train)=6.67e-04, grads_biases(train)=6.76e-03, acc(train)=9.91e-01, error(valid)=8.47e-02, grads_output(valid)=1.03e-04, grads_weights(valid)=6.67e-04, grads_biases(valid)=6.76e-03, acc(valid)=9.79e-01
# Epoch 40: 2.6s to complete
#     error(train)=1.95e-02, grads_output(train)=4.01e-05, grads_weights(train)=1.15e-03, grads_biases(train)=6.72e-03, acc(train)=9.95e-01, error(valid)=6.94e-02, grads_output(valid)=8.78e-05, grads_weights(valid)=1.15e-03, grads_biases(valid)=6.72e-03, acc(valid)=9.82e-01
# Epoch 45: 2.4s to complete
#     error(train)=2.51e-02, grads_output(train)=4.77e-05, grads_weights(train)=2.07e-05, grads_biases(train)=1.74e-04, acc(train)=9.93e-01, error(valid)=8.26e-02, grads_output(valid)=9.78e-05, grads_weights(valid)=2.07e-05, grads_biases(valid)=1.74e-04, acc(valid)=9.80e-01
# Epoch 50: 2.5s to complete
#     error(train)=1.94e-02, grads_output(train)=3.92e-05, grads_weights(train)=1.09e-03, grads_biases(train)=8.03e-03, acc(train)=9.94e-01, error(valid)=7.85e-02, grads_output(valid)=9.00e-05, grads_weights(valid)=1.09e-03, grads_biases(valid)=8.03e-03, acc(valid)=9.81e-01
# Epoch 55: 2.4s to complete
#     error(train)=1.78e-02, grads_output(train)=3.45e-05, grads_weights(train)=4.62e-04, grads_biases(train)=3.69e-03, acc(train)=9.95e-01, error(valid)=7.42e-02, grads_output(valid)=8.69e-05, grads_weights(valid)=4.62e-04, grads_biases(valid)=3.69e-03, acc(valid)=9.81e-01
# Epoch 60: 2.4s to complete
#     error(train)=1.66e-02, grads_output(train)=3.39e-05, grads_weights(train)=1.01e-04, grads_biases(train)=7.19e-04, acc(train)=9.95e-01, error(valid)=7.66e-02, grads_output(valid)=9.13e-05, grads_weights(valid)=1.01e-04, grads_biases(valid)=7.19e-04, acc(valid)=9.81e-01
# Epoch 65: 2.4s to complete
#     error(train)=1.77e-02, grads_output(train)=3.33e-05, grads_weights(train)=5.33e-05, grads_biases(train)=4.03e-04, acc(train)=9.95e-01, error(valid)=7.92e-02, grads_output(valid)=9.22e-05, grads_weights(valid)=5.33e-05, grads_biases(valid)=4.03e-04, acc(valid)=9.80e-01
# Epoch 70: 2.4s to complete
#     error(train)=1.56e-02, grads_output(train)=3.00e-05, grads_weights(train)=1.28e-03, grads_biases(train)=1.28e-02, acc(train)=9.96e-01, error(valid)=7.29e-02, grads_output(valid)=8.64e-05, grads_weights(valid)=1.28e-03, grads_biases(valid)=1.28e-02, acc(valid)=9.81e-01
# Epoch 75: 2.4s to complete
#     error(train)=1.76e-02, grads_output(train)=3.36e-05, grads_weights(train)=1.22e-03, grads_biases(train)=7.61e-03, acc(train)=9.95e-01, error(valid)=7.68e-02, grads_output(valid)=9.15e-05, grads_weights(valid)=1.22e-03, grads_biases(valid)=7.61e-03, acc(valid)=9.80e-01
# Epoch 80: 2.4s to complete
#     error(train)=1.65e-02, grads_output(train)=3.05e-05, grads_weights(train)=3.66e-04, grads_biases(train)=1.57e-03, acc(train)=9.95e-01, error(valid)=7.52e-02, grads_output(valid)=8.19e-05, grads_weights(valid)=3.66e-04, grads_biases(valid)=1.57e-03, acc(valid)=9.83e-01
# Epoch 85: 2.4s to complete
#     error(train)=1.49e-02, grads_output(train)=2.70e-05, grads_weights(train)=8.14e-05, grads_biases(train)=6.48e-04, acc(train)=9.96e-01, error(valid)=7.30e-02, grads_output(valid)=7.97e-05, grads_weights(valid)=8.14e-05, grads_biases(valid)=6.48e-04, acc(valid)=9.83e-01
# Epoch 90: 2.4s to complete
#     error(train)=1.25e-02, grads_output(train)=2.58e-05, grads_weights(train)=5.72e-04, grads_biases(train)=4.40e-03, acc(train)=9.96e-01, error(valid)=7.61e-02, grads_output(valid)=8.44e-05, grads_weights(valid)=5.72e-04, grads_biases(valid)=4.40e-03, acc(valid)=9.82e-01
# Epoch 95: 2.4s to complete
#     error(train)=1.40e-02, grads_output(train)=2.52e-05, grads_weights(train)=3.20e-04, grads_biases(train)=3.59e-03, acc(train)=9.96e-01, error(valid)=7.80e-02, grads_output(valid)=8.24e-05, grads_weights(valid)=3.20e-04, grads_biases(valid)=3.59e-03, acc(valid)=9.82e-01
# Epoch 100: 2.4s to complete
#     error(train)=1.39e-02, grads_output(train)=2.53e-05, grads_weights(train)=5.44e-04, grads_biases(train)=3.46e-03, acc(train)=9.96e-01, error(valid)=7.84e-02, grads_output(valid)=8.25e-05, grads_weights(valid)=5.44e-04, grads_biases(valid)=3.46e-03, acc(valid)=9.81e-01

# %% [markdown]
# ---
#
# **Notes**
#
# The augmented data increases the training error. This is expected since the dataset can be seen as "infinite", it cannot be easily memorised by the model.
#
# The validation set error is lower than other regularisation model, meaning this is the best performing model.
#
# By augmenting the data we have introduced a useful domain specific _prior_ in the model : e.g. be invariant to small rotations.
#
# ---
